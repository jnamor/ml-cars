# %%
import pandas as pd
import json

# %%
start_urls = []
with open('data/data_harvest_full.json','r') as sample:
    for line in sample:
        start_urls.append(json.loads(line.strip()))

# %%
start_urls
# Out:
# [{'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/duster/1260688891A1KVVODCDUS',
#   'status': 200,
#   'location': 'dissay (86130)',
#   'version': 'version duster tce 130 fap 4x2 prestige',
#   'price': 'prix 17 600 €',
#   'year': "année février 2019 le comparateur d'assurance pour cette dacia duster",
#   'mileage': 'kilométrage 18 300 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '130',
#   'body_colour': 'blanc',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mini/cooper/1260799421A1KVVOMCCOO',
#   'status': 200,
#   'location': '59240 dunkerque',
#   'version': 'version cooper s red hot chili 192 cv bva',
#   'price': 'prix 24 990 €',
#   'year': "année mai 2018 le comparateur d'assurance pour cette mini cooper",
#   'mileage': 'kilométrage 47 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 119 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 10 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '192',
#   'body_colour': 'rouge foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/nissan/qashqai/1260796406A1KVVONIQAS',
#   'status': 200,
#   'location': '53000 laval',
#   'version': 'version 1.5 dci 110ch fap ultimate edition',
#   'price': 'prix 8 490 €',
#   'year': "année octobre 2013 le comparateur d'assurance pour cette nissan qashqai",
#   'mileage': 'kilométrage 166 400 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 129 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '110',
#   'body_colour': 'gris',
#   'body_type': 'break'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/nissan/qashqai/1260447237A1KVVONIQAS',
#   'status': 200,
#   'location': 'belley (01300)',
#   'version': 'version qashqai 1.6 dci 130 xtronic tekna',
#   'price': 'prix 16 900 €',
#   'year': "année octobre 2016 le comparateur d'assurance pour cette nissan qashqai",
#   'mileage': 'kilométrage 61 500 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 128 g/km',
#   'fuel_usage': 'consommation mixte 4.9 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '130',
#   'body_colour': 'gris foncé',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mini/cooper/1258307414A1KVVOMCCOO',
#   'status': 200,
#   'location': '30200 bagnols-sur-cèze',
#   'version': 'version one d 95 ch edition blackfriars',
#   'price': 'prix 17 900 €',
#   'year': "année février 2018 le comparateur d'assurance pour cette mini cooper",
#   'mileage': 'kilométrage 58 529 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 99 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '95',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mini/cooper/1260766816A1KVVOMCCOO',
#   'status': 200,
#   'location': 'luxeuil-les-bains (70300)',
#   'version': 'version mini cooper 136 ch edition blackfriars',
#   'price': 'prix 17 800 €',
#   'year': "année décembre 2017 le comparateur d'assurance pour cette mini cooper",
#   'mileage': 'kilométrage 58 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 107 g/km',
#   'fuel_usage': 'consommation mixte 4.6 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '136',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mini/cooper/1260799204A1KVVOMCCOO',
#   'status': 200,
#   'location': '67120 dachstein',
#   'version': 'version mini cabriolet 231 ch john cooper works bva8',
#   'price': 'prix 31 900 €',
#   'year': "année juin 2018 le comparateur d'assurance pour cette mini cooper",
#   'mileage': 'kilométrage 41 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 136 g/km',
#   'fuel_usage': 'consommation mixte 5.9 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 2 portes',
#   'technical_power': 'puissance fiscale 14 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': 'N/A',
#   'body_colour': 'bleu clair',
#   'body_type': 'cabriolet'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/duster/1260081050A1KVVODCDUS',
#   'status': 200,
#   'location': 'dun-sur-auron (18130)',
#   'version': 'version duster dci 110 edc 4x2 confort',
#   'price': 'prix 15 400 €',
#   'year': "année août 2018 le comparateur d'assurance pour cette dacia duster",
#   'mileage': 'kilométrage 36 500 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 116 g/km',
#   'fuel_usage': 'consommation mixte 4.5 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '110',
#   'body_colour': 'blanc',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260806331A1KVVOFI500',
#   'status': 200,
#   'location': '31390 carbonne',
#   'version': 'version ii 1.2 8v s&s pop',
#   'price': 'prix 6 900 €',
#   'year': "année juillet 2010 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 105 733 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/duster/1259756816A1KVVODCDUS',
#   'status': 200,
#   'location': 'porto-vecchio (20137)',
#   'version': 'version duster 1.5 dci 110 4x2 ambiance',
#   'price': 'prix 8 000 €',
#   'year': "année mars 2012 le comparateur d'assurance pour cette dacia duster",
#   'mileage': 'kilométrage 124 111 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 130 g/km',
#   'fuel_usage': 'consommation mixte 5.0 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '107',
#   'body_colour': 'gris clair',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/duster/1259407566A1KVVODCDUS',
#   'status': 200,
#   'location': 'muides-sur-loire (41500)',
#   'version': 'version duster 1.5 dci 110 e6 4x2 prestige',
#   'price': 'prix 12 900 €',
#   'year': "année mars 2016 le comparateur d'assurance pour cette dacia duster",
#   'mileage': 'kilométrage 86 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 115 g/km',
#   'fuel_usage': 'consommation mixte 4.4 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '110',
#   'body_colour': 'noir',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds3/1260410272A1KVVOCIDS3',
#   'status': 200,
#   'location': 'beynes (78650)',
#   'version': 'version ds3 e-hdi 90 so chic',
#   'price': 'prix 8 790 €',
#   'year': "année novembre 2014 le comparateur d'assurance pour cette citroën ds3",
#   'mileage': 'kilométrage 97 400 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 90 g/km',
#   'fuel_usage': 'consommation mixte 3.5 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '92',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260350777A1KVVOFI500',
#   'status': 200,
#   'location': 'amiens (80000)',
#   'version': 'version 500 1.2 8v 69 ch lounge',
#   'price': 'prix 6 900 €',
#   'year': "année janvier 2014 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 58 200 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 119 g/km',
#   'fuel_usage': 'consommation mixte 5.1 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '69',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1219545820A1KVVOVWGOL',
#   'status': 200,
#   'location': 'saint-vincent-sterlanges (85110)',
#   'version': 'version golf tdi 90 s',
#   'price': 'prix 2 800 €',
#   'year': "année janvier 1995 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 239 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '90',
#   'body_colour': 'bleu foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260802281A1KVVOFI500',
#   'status': 200,
#   'location': '62223 saint-laurent-blangy',
#   'version': 'version 500 1.2 69 ch eco pack s/s star',
#   'price': 'prix 12 490 €',
#   'year': "année mars 2020 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 14 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 109 g/km',
#   'fuel_usage': 'consommation mixte 5.1 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds7/1260778213A1KVVOCIDS7',
#   'status': 200,
#   'location': '79180 chauray',
#   'version': 'version bluehdi 180 eat8 performance line',
#   'price': 'prix 30 990 €',
#   'year': "année janvier 2019 le comparateur d'assurance pour cette citroën ds7",
#   'mileage': 'kilométrage 62 614 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 9 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'rouge clair',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1260773672A1KVVOVWGOL',
#   'status': 200,
#   'location': 'flétrange (57690)',
#   'version': 'version golf 1.9 tdi - 90 a',
#   'price': 'prix 900 €',
#   'year': "année mars 2000 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 203 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 172 g/km',
#   'fuel_usage': 'consommation mixte 6.3 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '90',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1258574087A1KVVOVWGOL',
#   'status': 200,
#   'location': 'nîmes (30000)',
#   'version': 'version golf 2.0 tsi 270 r 4motion dsg6',
#   'price': 'prix 19 900 €',
#   'year': "année décembre 2011 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 117 300 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 195 g/km',
#   'fuel_usage': 'consommation mixte 8.4 litres / 100 km',
#   'transmission': 'transmission semi automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 17 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '270',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260502419A1KVVOFI500',
#   'status': 200,
#   'location': 'lattes (34970)',
#   'version': 'version 500 1.2 69 ch lounge',
#   'price': 'prix 9 600 €',
#   'year': "année juin 2016 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 30 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 115 g/km',
#   'fuel_usage': 'consommation mixte 4.9 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '69',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/opel/corsa/1260800422A1KVVOOPCOR',
#   'status': 200,
#   'location': '69780 mions',
#   'version': 'version 1.2 70 enjoy 5p',
#   'price': 'prix 8 990 €',
#   'year': "année mars 2016 le comparateur d'assurance pour cette opel corsa",
#   'mileage': 'kilométrage 48 830 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds7/1260471943A1KVVOCIDS7',
#   'status': 200,
#   'location': "81380 lescure-d'albigeois",
#   'version': 'version bluehdi 180 eat8 grand chic cuir toit ouvrant 1°main',
#   'price': 'prix 41 980 €',
#   'year': "année février 2020 le comparateur d'assurance pour cette citroën ds7",
#   'mileage': 'kilométrage 26 400 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 113 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 9 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '180',
#   'body_colour': 'gris platinium',
#   'body_type': 'N/A'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds7/1260798870A1KVVOCIDS7',
#   'status': 200,
#   'location': '38320 eybens',
#   'version': 'N/A',
#   'price': 'prix 61 980 €',
#   'year': "année 2021 le comparateur d'assurance pour cette citroën ds7",
#   'mileage': 'kilométrage 5 605 km',
#   'fuel_type': 'N/A',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 11 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '200',
#   'body_colour': 'blanc',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260806188A1KVVOFI500',
#   'status': 200,
#   'location': '06400 cannes',
#   'version': 'version 500 1.2 8v 69 ch lounge',
#   'price': 'prix 8 190 €',
#   'year': "année mai 2015 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 50 100 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 117 g/km',
#   'fuel_usage': 'consommation mixte 5.0 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': 'N/A',
#   'body_colour': 'noir',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1258116307A1KVVOFI500',
#   'status': 200,
#   'location': 'port-de-bouc (13110)',
#   'version': 'version 500 0.9 85 ch twinair s&s anniversario',
#   'price': 'prix 7 500 €',
#   'year': "année avril 2018 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 56 700 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 90 g/km',
#   'fuel_usage': 'consommation mixte 3.8 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '85',
#   'body_colour': 'bordeaux',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260803521A1KVVOSELEO',
#   'status': 200,
#   'location': '42320 la grand-croix',
#   'version': 'version nouvelle 1.5 etsi 150 dsg7 fr',
#   'price': 'prix 32 398 €',
#   'year': "année janvier 2022 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 11 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission autres',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 8 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1260433717A1KVVOVWGOL',
#   'status': 200,
#   'location': 'malakoff (92240)',
#   'version': 'version golf 1.5 tsi 130 evo bvm6 connect',
#   'price': 'prix 19 900 €',
#   'year': "année janvier 2019 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 24 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 117 g/km',
#   'fuel_usage': 'consommation mixte 5.0 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '130',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds7/1259450420A1KVVOCIDS7',
#   'status': 200,
#   'location': '54000 nancy',
#   'version': 'version 1.6 puretech 180 eat8 so chic+camera+carplay',
#   'price': 'prix 31 990 €',
#   'year': "année octobre 2018 le comparateur d'assurance pour cette citroën ds7",
#   'mileage': 'kilométrage 14 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 132 g/km',
#   'fuel_usage': 'consommation mixte 5.8 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 10 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'noir',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1258716311A1KVVODCSAN',
#   'status': 200,
#   'location': 'montpellier (34000)',
#   'version': 'version sandero sce 75',
#   'price': 'prix 10 500 €',
#   'year': "année novembre 2018 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 17 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 117 g/km',
#   'fuel_usage': 'consommation mixte 5.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '73',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260785309A1KVVOSELEO',
#   'status': 200,
#   'location': '29200 brest',
#   'version': 'version fr 1.5 tsi 150ch automatique',
#   'price': 'prix 21 970 €',
#   'year': "année novembre 2019 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 44 404 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 114.0 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'N/A',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1259981075A1KVVOVWGOL',
#   'status': 200,
#   'location': 'villecerf (77250)',
#   'version': 'version golf 1.4i',
#   'price': 'prix 2 250 €',
#   'year': "année novembre 1999 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 191 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 158 g/km',
#   'fuel_usage': 'consommation mixte 6.6 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1256975772A1KVVOMEA',
#   'status': 200,
#   'location': 'pompignan (82170)',
#   'version': 'version classe a 180 d 8g-dct amg line',
#   'price': 'prix 30 000 €',
#   'year': "année décembre 2018 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 24 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260785269A1KVVOSELEO',
#   'status': 200,
#   'location': '13011 marseille',
#   'version': 'version fr 1.5 tsi 150ch automatique',
#   'price': 'prix 21 970 €',
#   'year': "année novembre 2019 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 44 404 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 114.0 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'N/A',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1236126426A1KVVODCSAN',
#   'status': 200,
#   'location': 'caen (14000)',
#   'version': 'version sandero tce 90 - 22 stepway confort',
#   'price': 'prix 13 600 €',
#   'year': "année janvier 2022 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 1 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '92',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/opel/corsa/1260804528A1KVVOOPCOR',
#   'status': 200,
#   'location': '33380 biganos',
#   'version': 'version electrique 136cv 50kw elegance',
#   'price': 'prix 25 750 €',
#   'year': "année octobre 2020 le comparateur d'assurance pour cette opel corsa",
#   'mileage': 'kilométrage 25 km',
#   'fuel_type': 'energie electrique',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/opel/corsa/1251339248A1KVVOOPCOR',
#   'status': 200,
#   'location': 'loos (59120)',
#   'version': 'version corsa 1.2 - 80 twinport enjoy',
#   'price': 'prix 3 200 €',
#   'year': "année juin 2009 le comparateur d'assurance pour cette opel corsa",
#   'mileage': 'kilométrage 170 440 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 146 g/km',
#   'fuel_usage': 'consommation mixte 6.1 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '80',
#   'body_colour': 'noir',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/citroen/ds7/1260784372A1KVVOCIDS7',
#   'status': 200,
#   'location': '35240 le theil-de-bretagne',
#   'version': 'version ds7 crossback bluehdi 130 bvm6 executive',
#   'price': 'prix 26 800 €',
#   'year': "année juillet 2018 le comparateur d'assurance pour cette citroën ds7",
#   'mileage': 'kilométrage 128 740 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 102 g/km',
#   'fuel_usage': 'consommation mixte 3.9 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'or',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/fiat/500/1260335503A1KVVOFI500',
#   'status': 200,
#   'location': '06800 cagnes-sur-mer',
#   'version': 'version 500 1.2 69 ch eco pack s/s lounge',
#   'price': 'prix 10 990 €',
#   'year': "année août 2019 le comparateur d'assurance pour cette fiat 500",
#   'mileage': 'kilométrage 58 490 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 109 g/km',
#   'fuel_usage': 'consommation mixte 5.1 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': 'N/A',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1258618188A1KVVOMEA',
#   'status': 200,
#   'location': 'nice (06000)',
#   'version': 'version a160 avantgarde',
#   'price': 'prix 3 300 €',
#   'year': "année septembre 1999 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 175 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 172 g/km',
#   'fuel_usage': 'consommation mixte 7.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '102',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1257439633A1KVVOMEA',
#   'status': 200,
#   'location': 'le cannet (06110)',
#   'version': 'version classe a 180 7g-dct amg line',
#   'price': 'prix 33 750 €',
#   'year': "année janvier 2021 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 3 395 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '136',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1258315236A1KVVOSELEO',
#   'status': 200,
#   'location': '33510 andernos-les-bains',
#   'version': 'version leon 1.2 tsi réference copa ecomotive',
#   'price': 'prix 9 999 €',
#   'year': "année octobre 2012 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 80 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 124 g/km',
#   'fuel_usage': 'consommation mixte 5.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1259820014A1KVVOTOYAR',
#   'status': 200,
#   'location': 'fontenay-le-fleury (78330)',
#   'version': 'version yaris hybride 100h skyblue',
#   'price': 'prix 11 800 €',
#   'year': "année mars 2016 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 85 248 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'emissions de co2 82 g/km',
#   'fuel_usage': 'consommation mixte 3.6 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260399621A1KVVOSELEO',
#   'status': 200,
#   'location': '94500 champigny-sur-marne',
#   'version': 'version 1.4 tsi 150ch act i-tech start&stop',
#   'price': 'prix 13 890 €',
#   'year': "année octobre 2014 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 96 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 109 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '150',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1260784833A1KVVODCSAN',
#   'status': 200,
#   'location': 'aubevoye (27940)',
#   'version': 'version sandero tce 90 - 22 confort',
#   'price': 'prix 14 900 €',
#   'year': "année mars 2022 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 60 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '92',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1254395608A1KVVOTOYAR',
#   'status': 200,
#   'location': 'allinges (74200)',
#   'version': 'version yaris hybride 100h chic',
#   'price': 'prix 15 490 €',
#   'year': "année juillet 2018 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 10 515 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'emissions de co2 82 g/km',
#   'fuel_usage': 'consommation mixte 3.6 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '105',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volkswagen/golf/1260628140A1KVVOVWGOL',
#   'status': 200,
#   'location': 'huningue (68330)',
#   'version': 'version golf 1.4 tsi 122 bluemotion technology carat',
#   'price': 'prix 11 000 €',
#   'year': "année octobre 2014 le comparateur d'assurance pour cette volkswagen golf",
#   'mileage': 'kilométrage 117 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 120 g/km',
#   'fuel_usage': 'consommation mixte 5.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '122',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260805136A1KVVOTOYAR',
#   'status': 200,
#   'location': '51100 reims',
#   'version': 'version 1.0 - 69 vvt-i iii 2011 dynamic phase 2',
#   'price': 'prix 8 490 €',
#   'year': "année 2014 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 68 274 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '69',
#   'body_colour': 'bleu clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260803524A1KVVOSELEO',
#   'status': 200,
#   'location': '42320 la grand-croix',
#   'version': 'version nouvelle 1.5 etsi 150 dsg7 fr',
#   'price': 'prix 31 883 €',
#   'year': "année janvier 2022 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 10 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission autres',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 8 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/peugeot/208/1260435912A1KVVOPE208',
#   'status': 200,
#   'location': '38120 saint-égrève',
#   'version': 'version allure pack 1.2 puretech s&s 100ch',
#   'price': 'prix 22 370 €',
#   'year': "année 2022 le comparateur d'assurance pour cette peugeot 208",
#   'mileage': 'kilométrage 10 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'gris artense',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260331359A1KVVOTOYAR',
#   'status': 200,
#   'location': '30620 bernis',
#   'version': 'version 1.4 - 90 d-4d luna',
#   'price': 'prix 5 500 €',
#   'year': "année mars 2007 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 123 127 km',
#   'fuel_type': 'N/A',
#   'emission': 'emissions de co2 119 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '90',
#   'body_colour': 'gris fonce',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1260801607A1KVVODCSAN',
#   'status': 200,
#   'location': '06250 mougins',
#   'version': 'version tce 90 stepway confort',
#   'price': 'prix 18 890 €',
#   'year': "année 2021 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 10 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'N/A',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'N/A',
#   'body_type': 'N/A'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260785240A1KVVOSELEO',
#   'status': 200,
#   'location': '67450 mundolsheim',
#   'version': 'version fr 1.5 tsi 150ch automatique',
#   'price': 'prix 21 970 €',
#   'year': "année novembre 2019 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 44 404 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 114.0 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'N/A',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'gris',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260691564A1KVVOTOYAR',
#   'status': 200,
#   'location': 'saint-savinien (17350)',
#   'version': 'version yaris hybride 100h dynamic',
#   'price': 'prix 16 500 €',
#   'year': "année juin 2020 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 23 753 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'emissions de co2 84 g/km',
#   'fuel_usage': 'consommation mixte 3.6 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1260803232A1KVVODCSAN',
#   'status': 200,
#   'location': 'saint-vivien-de-médoc (33590)',
#   'version': 'version sandero 1.5 dci 90 e6 stepway prestige',
#   'price': 'prix 10 200 €',
#   'year': "année mars 2016 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 69 250 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 98 g/km',
#   'fuel_usage': 'consommation mixte 3.8 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '90',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1259763273A1KVVODCSAN',
#   'status': 200,
#   'location': 'lavaur (81500)',
#   'version': 'version sandero 1.5 dci 90 e6 stepway prestige',
#   'price': 'prix 11 200 €',
#   'year': "année février 2016 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 25 800 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 98 g/km',
#   'fuel_usage': 'consommation mixte 3.8 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '90',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260798710A1KVVOTOYAR',
#   'status': 200,
#   'location': '92600 asnières-sur-seine',
#   'version': 'N/A',
#   'price': 'prix 13 790 €',
#   'year': "année 2015 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 36 039 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/opel/corsa/1260657154A1KVVOOPCOR',
#   'status': 200,
#   'location': '66250 saint-laurent-de-la-salanque',
#   'version': 'version 1.2 twinport edition gpl 3p',
#   'price': 'prix 3 490 €',
#   'year': "année septembre 2011 le comparateur d'assurance pour cette opel corsa",
#   'mileage': 'kilométrage 199 763 km',
#   'fuel_type': 'energie gpl ou gnl',
#   'emission': 'emissions de co2 110 g/km',
#   'fuel_usage': 'consommation mixte 6.8 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '83',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260634039A1KVVOTOYAR',
#   'status': 200,
#   'location': '75008 paris',
#   'version': 'version design 1.0 vvt-i 70',
#   'price': 'prix 12 980 €',
#   'year': "année octobre 2018 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 2 537 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/sandero/1260217477A1KVVODCSAN',
#   'status': 200,
#   'location': 'le perray-en-yvelines (78610)',
#   'version': 'version sandero tce 90 confort',
#   'price': 'prix 15 000 €',
#   'year': "année août 2021 le comparateur d'assurance pour cette dacia sandero",
#   'mileage': 'kilométrage 4 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 127 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '92',
#   'body_colour': 'orange',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/peugeot/208/1260806328A1KVVOPE208',
#   'status': 200,
#   'location': '22000 saint-brieuc',
#   'version': 'version puretech 130 s&s eat8 allure pack',
#   'price': 'prix 22 490 €',
#   'year': "année janvier 2021 le comparateur d'assurance pour cette peugeot 208",
#   'mileage': 'kilométrage 7 236 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/seat/leon/1260799894A1KVVOSELEO',
#   'status': 200,
#   'location': '25440 quingey',
#   'version': 'version nouvelle 1.5 etsi 150 dsg7 fr',
#   'price': 'prix 31 398 €',
#   'year': "année janvier 2022 le comparateur d'assurance pour cette seat leon",
#   'mileage': 'kilométrage 11 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission autres',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 8 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'rouge',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1260805502A1KVVOMEA',
#   'status': 200,
#   'location': '56600 lanester',
#   'version': 'version 180 d 116ch business line',
#   'price': 'prix 35 980 €',
#   'year': "année décembre 2019 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 57 227 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 100 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'N/A',
#   'actual_power': '116',
#   'body_colour': 'noir',
#   'body_type': 'break'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1260754480A1KVVOMEA',
#   'status': 200,
#   'location': 'les abrets (38490)',
#   'version': 'version classe a 180 d 7g-dct amg line',
#   'price': 'prix 26 300 €',
#   'year': "année janvier 2019 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 69 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '116',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260597101A1KVVOTOYAR',
#   'status': 200,
#   'location': 'saint-germain-des-fossés (03260)',
#   'version': 'version yaris hybride 100h collection jaune',
#   'price': 'prix 14 800 €',
#   'year': "année octobre 2017 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 26 600 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'emissions de co2 82 g/km',
#   'fuel_usage': 'consommation mixte 3.6 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'jaune',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1260606505A1KVVOMEA',
#   'status': 200,
#   'location': 'ventiseri (20240)',
#   'version': 'version classe a 200 cdi blueefficiency business',
#   'price': 'prix 17 000 €',
#   'year': "année novembre 2015 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 146 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 109 g/km',
#   'fuel_usage': 'consommation mixte 4.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '136',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/toyota/yaris/1260805425A1KVVOTOYAR',
#   'status': 200,
#   'location': '41250 neuvy',
#   'version': 'version hybrid 100h france',
#   'price': 'prix 12 690 €',
#   'year': "année 2016 le comparateur d'assurance pour cette toyota yaris",
#   'mileage': 'kilométrage 28 877 km',
#   'fuel_type': 'N/A',
#   'emission': 'emissions de co2 75 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'N/A',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 3 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '99',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1257706499A1KVVOMEA',
#   'status': 200,
#   'location': 'cuts (60400)',
#   'version': 'version classe a 180 d 7g-dct amg line',
#   'price': 'prix 28 000 €',
#   'year': "année août 2019 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 36 500 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '116',
#   'body_colour': 'noir',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mercedes/classe-a/1259910257A1KVVOMEA',
#   'status': 200,
#   'location': 'sézanne (51120)',
#   'version': 'version classe a 220 cdi blueefficiency 4-matic fascination 7-g dct a',
#   'price': 'prix 17 490 €',
#   'year': "année juin 2014 le comparateur d'assurance pour cette mercedes classe a",
#   'mileage': 'kilométrage 164 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 127 g/km',
#   'fuel_usage': 'consommation mixte 4.9 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 9 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '170',
#   'body_colour': 'N/A',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/peugeot/208/1258912201A1KVVOPE208',
#   'status': 200,
#   'location': 'noidans-lès-vesoul (70000)',
#   'version': 'version 208 puretech 100 s&s bvm6 gt pack',
#   'price': 'prix 21 500 €',
#   'year': "année février 2021 le comparateur d'assurance pour cette peugeot 208",
#   'mileage': 'kilométrage 7 500 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
# ...
#   'actual_power': 'N/A',
#   'body_colour': 'bleu',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/skoda/fabia/1253064689A1KVVOSKFAB',
#   'status': 200,
#   'location': 'cannes (06400)',
#   'version': 'version fabia combi 1.6 tdi 105 cr elegance 2',
#   'price': 'prix 3 500 €',
#   'year': "année juin 2013 le comparateur d'assurance pour cette skoda fabia",
#   'mileage': 'kilométrage 209 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 109 g/km',
#   'fuel_usage': 'consommation mixte 4.2 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '105',
#   'body_colour': 'blanc',
#   'body_type': 'break'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volvo/v40/1260089865A1KVVOVOV40',
#   'status': 200,
#   'location': '67460 souffelweyersheim',
#   'version': 'version t2 122ch momentum business gps led radar ar',
#   'price': 'prix 16 999 €',
#   'year': "année décembre 2016 le comparateur d'assurance pour cette volvo v40",
#   'mileage': 'kilométrage 47 648 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 127 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '122',
#   'body_colour': 'noir',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mini/clubman/1260800702A1KVVOMCCLU',
#   'status': 200,
#   'location': '66450 pollestres',
#   'version': 'version cooper s all4 2.0 192ch finition john cooper works',
#   'price': 'prix 20 490 €',
#   'year': "année juin 2016 le comparateur d'assurance pour cette mini clubman",
#   'mileage': 'kilométrage 44 770 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 162 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 11 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '192',
#   'body_colour': 'gris clair',
#   'body_type': 'break'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/x2/1256299209A1KVVOBMX2',
#   'status': 200,
#   'location': "81380 lescure-d'albigeois",
#   'version': 'version (f39) xdrive 20da 190 bva8 m sport gps caméra toit ja 19"',
#   'price': 'prix 43 950 €',
#   'year': "année août 2021 le comparateur d'assurance pour cette bmw x2",
#   'mileage': 'kilométrage 6 500 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 10 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '190',
#   'body_colour': 'misano blau metal',
#   'body_type': 'N/A'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/x2/1256299208A1KVVOBMX2',
#   'status': 200,
#   'location': "81380 lescure-d'albigeois",
#   'version': 'version (f40) sdrive 18da 150 bva8 msport gps caméra toit ja 19"',
#   'price': 'prix 41 650 €',
#   'year': "année août 2021 le comparateur d'assurance pour cette bmw x2",
#   'mileage': 'kilométrage 9 100 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 8 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '150',
#   'body_colour': 'misano blau metal',
#   'body_type': 'N/A'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volvo/v40/1260497276A1KVVOVOV40',
#   'status': 200,
#   'location': '22300 lannion',
#   'version': 'version ii d2 1.6 tdi dpf s&s 115 cv momentum',
#   'price': 'prix 9 490 €',
#   'year': "année octobre 2012 le comparateur d'assurance pour cette volvo v40",
#   'mileage': 'kilométrage 140 900 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'N/A',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '115',
#   'body_colour': 'rouge fonce',
#   'body_type': 'N/A'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volvo/v40/1259784060A1KVVOVOV40',
#   'status': 200,
#   'location': '75008 paris',
#   'version': 'version momentum business d2 115 powershift',
#   'price': 'prix 10 990 €',
#   'year': "année septembre 2014 le comparateur d'assurance pour cette volvo v40",
#   'mileage': 'kilométrage 90 084 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/x2/1259661754A1KVVOBMX2',
#   'status': 200,
#   'location': 'marseille (13009)',
#   'version': 'version x2 xdrive 20d 190 ch bva8 m sport x',
#   'price': 'prix 37 000 €',
#   'year': "année novembre 2017 le comparateur d'assurance pour cette bmw x2",
#   'mileage': 'kilométrage 25 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 126 g/km',
#   'fuel_usage': 'consommation mixte 4.8 litres / 100 km',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 10 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '190',
#   'body_colour': 'blanc',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/hyundai/i20/1260147759A1KVVOHYI20',
#   'status': 200,
#   'location': '30800 saint-gilles',
#   'version': 'version 1.0l t-gdi 100ch evap garantie',
#   'price': 'prix 11 490 €',
#   'year': "année 2020 le comparateur d'assurance pour cette hyundai i20",
#   'mileage': 'kilométrage 13 855 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '101',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/dacia/lodgy/1260006524A1KVVODCLOD',
#   'status': 200,
#   'location': '30800 saint-gilles',
#   'version': 'version 1.5 dci 110 7 places révisé/garantie',
#   'price': 'prix 4 790 €',
#   'year': "année mai 2012 le comparateur d'assurance pour cette dacia lodgy",
#   'mileage': 'kilométrage 199 980 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 5',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 7 places',
#   'actual_power': '107',
#   'body_colour': 'gris foncé',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/jeep/compass/1247676140A1KVVOJEPAS',
#   'status': 200,
#   'location': '25770 franois',
#   'version': 'version 1.3 gse t4 190ch limited 4xe phev at6 gps camera',
#   'price': 'prix 34 499 €',
#   'year': "année août 2020 le comparateur d'assurance pour cette jeep compass",
#   'mileage': 'kilométrage 7 350 km',
#   'fuel_type': 'energie hybride',
#   'emission': 'emissions de co2 48 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '130',
#   'body_colour': 'glacier',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/serie-4/1259862107A1KVVOBMS4',
#   'status': 200,
#   'location': '01750 replonges',
#   'version': 'version 420 da coupé 190cv pack m dispo',
#   'price': 'prix 47 490 €',
#   'year': "année 2021 le comparateur d'assurance pour cette bmw série 4",
#   'mileage': 'kilométrage 13 500 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'N/A',
#   'seat_nb': 'N/A',
#   'actual_power': '190',
#   'body_colour': 'bleu',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/x2/1258774849A1KVVOBMX2',
#   'status': 200,
#   'location': '06250 mougins',
#   'version': 'version xdrive20d 190 bva8 premiã¨re surã©quipã©e',
#   'price': 'prix 24 499 €',
#   'year': "année 2018 le comparateur d'assurance pour cette bmw x2",
#   'mileage': 'kilométrage 98 643 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 124.0 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'N/A',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 10 cv',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'N/A',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/volvo/v40/1259751884A1KVVOVOV40',
#   'status': 200,
#   'location': '16160 gond-pontouvre',
#   'version': 'version v40 business d2 115 momentum business',
#   'price': 'prix 10 490 €',
#   'year': "année janvier 2015 le comparateur d'assurance pour cette volvo v40",
#   'mileage': 'kilométrage 150 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'emissions de co2 88 g/km',
#   'fuel_usage': 'consommation mixte 3.4 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mazda/cx-3/1260728371A1KVVOMACX3',
#   'status': 200,
#   'location': '06250 mougins',
#   'version': 'version skyactiv-d 1.5 d 105ch selection- garantie 6 mois',
#   'price': 'prix 11 990 €',
#   'year': "année novembre 2016 le comparateur d'assurance pour cette mazda cx-3",
#   'mileage': 'kilométrage 155 000 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'rouge clair',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/abarth/500/1260348345A1KVVOAB500',
#   'status': 200,
#   'location': '68110 illzach',
#   'version': 'version 1.4 turbo t-jet 135ch',
#   'price': 'prix 11 999 €',
#   'year': "année avril 2015 le comparateur d'assurance pour cette abarth 500",
#   'mileage': 'kilométrage 113 230 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 155 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 2 portes avec hayon',
#   'technical_power': 'puissance fiscale 8 cv',
#   'seat_nb': 'nombre de places 4 places',
#   'actual_power': '135',
#   'body_colour': 'gris clair',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mazda/cx-3/1260705933A1KVVOMACX3',
#   'status': 200,
#   'location': "59650 villeneuve-d'ascq",
#   'version': 'N/A',
#   'price': 'prix 13 990 €',
#   'year': "année 2016 le comparateur d'assurance pour cette mazda cx-3",
#   'mileage': 'kilométrage 65 328 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 5 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '105',
#   'body_colour': 'inconnu',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/bmw/x2/1259455152A1KVVOBMX2',
#   'status': 200,
#   'location': '40100 dax',
#   'version': 'version f39 sdrive 20i 192 ch dkg7 m sport',
#   'price': 'prix 38 150 €',
#   'year': "année février 2019 le comparateur d'assurance pour cette bmw x2",
#   'mileage': 'kilométrage 53 732 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 11 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': 'N/A',
#   'body_colour': 'blanc',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mazda/cx-3/1260745671A1KVVOMACX3',
#   'status': 200,
#   'location': '06250 mougins',
#   'version': 'version 2.0 skyactiv-g 121 bvm6 dynamique',
#   'price': 'prix 18 999 €',
#   'year': "année 2019 le comparateur d'assurance pour cette mazda cx-3",
#   'mileage': 'kilométrage 19 182 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 141.0 g/km',
#   'fuel_usage': 'N/A',
#   'transmission': 'N/A',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 7 cv',
#   'seat_nb': 'N/A',
#   'actual_power': 'N/A',
#   'body_colour': 'N/A',
#   'body_type': '4x4'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/skoda/fabia/1257380419A1KVVOSKFAB',
#   'status': 200,
#   'location': 'vandœuvre-lès-nancy (54500)',
#   'version': 'version fabia 1.0 mpi 60 ch bvm5 clever',
#   'price': 'prix 10 500 €',
#   'year': "année février 2019 le comparateur d'assurance pour cette skoda fabia",
#   'mileage': 'kilométrage 84 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 110 g/km',
#   'fuel_usage': 'consommation mixte 4.9 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '60',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/hyundai/i20/1260745214A1KVVOHYI20',
#   'status': 200,
#   'location': 'douvres-la-délivrande (14440)',
#   'version': 'version i20 1.2 75 edition #clim',
#   'price': 'prix 9 500 €',
#   'year': "année novembre 2017 le comparateur d'assurance pour cette hyundai i20",
#   'mileage': 'kilométrage 46 700 km',
#   'fuel_type': 'energie essence',
#   'emission': 'emissions de co2 112 g/km',
#   'fuel_usage': 'consommation mixte 4.8 litres / 100 km',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 4 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '75',
#   'body_colour': 'blanc',
#   'body_type': 'berline'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/peugeot/5008/1260804681A1KVVOPE5M8',
#   'status': 200,
#   'location': '75008 paris',
#   'version': 'version active business 7pl 1.6 bluehdi 120',
#   'price': 'prix 9 270 €',
#   'year': "année mai 2016 le comparateur d'assurance pour cette peugeot 5008",
#   'mileage': 'kilométrage 166 219 km',
#   'fuel_type': 'energie diesel',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission manuelle',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 7 places',
#   'actual_power': 'N/A',
#   'body_colour': 'noir',
#   'body_type': 'monospace'},
#  {'url': 'https://www.paruvendu.fr/a/voiture-occasion/mazda/cx-3/1252361481A1KVVOMACX3',
#   'status': 200,
#   'location': '63100 clermont-ferrand',
#   'version': 'version 2.0 skya-g 121 ba6 signature',
#   'price': 'prix 24 900 €',
#   'year': "année décembre 2020 le comparateur d'assurance pour cette mazda cx-3",
#   'mileage': 'kilométrage 3 000 km',
#   'fuel_type': 'energie essence',
#   'emission': 'N/A',
#   'fuel_usage': 'N/A',
#   'transmission': 'transmission automatique',
#   'door_nb': 'nb de portes 4 portes avec hayon',
#   'technical_power': 'puissance fiscale 6 cv',
#   'seat_nb': 'nombre de places 5 places',
#   'actual_power': '121',
#   'body_colour': 'rouge fonce',
#   'body_type': 'N/A'},
#  ...]

# %%
f = open('data/brands.json')
brands = json.load(f)
brands
# Out:
# {'Abarth': ['500', '595', '695', 'Abarth 124 spider', 'F595', 'Grande Punto'],
#  'Aiways': [],
#  'Aleko': ['2141', 'Divers'],
#  'Alfa-Romeo': [],
#  'Alpina': ['B10', 'B12', 'B3', 'B4', 'B5', 'B6', 'D4', 'Xd3', 'Divers'],
#  'Aro': ['Aro 10',
#   'Aro 24',
#   'Cross Lander',
#   'Forester',
#   'Pick-up',
#   'Spartana',
#   'Trapeurs',
#   'Divers'],
#  'Aston-Martin': [],
#  'Audi': ['100',
#   '200',
#   '80',
#   '90',
#   'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'Allroad',
#   'Coupé',
#   'E-TRON',
#   'Q2',
#   'Q3',
#   'Q4',
#   'Q5',
#   'Q7',
#   'Q8',
#   'R8',
#   'RS Q3',
#   'RS3',
#   'RS4',
#   'RS5',
#   'RS6',
#   'S3',
#   'S4',
#   'S5',
#   'S6',
#   'S8',
#   'SQ5',
#   'SQ7',
#   'SQ8',
#   'TT',
#   'TT S',
#   'V8',
#   'Divers'],
#  'Austin': ['Autres', 'Mini'],
#  'Autres': [],
#  'Auverland': ['A3', 'A4', 'Divers'],
#  'BMW': ['i3',
#   'i4',
#   'i8',
#   'iX',
#   'iX3',
#   'M2',
#   'M3',
#   'M4',
#   'M5',
#   'M6',
#   'Série 1',
#   'Serie 2',
#   'Série 3',
#   'Série 4',
#   'Série 5',
#   'Série 6',
#   'Série 7',
#   'Série 8',
#   'X1',
#   'X2',
#   'X3',
#   'X4',
#   'X5',
#   'X6',
#   'X7',
#   'Z1',
#   'Z3',
#   'Z4',
#   'Z8',
#   'Divers'],
#  'Bentley': [],
#  'Bertone': ['Free Climber'],
#  'Buggy': ['Autres', 'Baboulin', 'DuneBuggy', 'LM1'],
#  'Buick': ['Park Avenue', 'Divers'],
#  'Cadillac': ['Allante',
#   'ATS',
#   'BLS',
#   'CTS',
#   'Eldorado',
#   'Escalade',
#   'Fleetwood',
#   'Seville',
#   'SRX',
#   'STS',
#   'XLR',
#   'Divers'],
#  'Caterham': [],
#  'Chevrolet': ['Alero',
#   'Aveo',
#   'Beretta',
#   'Blazer',
#   'Camaro',
#   'Captiva',
#   'Corsica',
#   'Corvette',
#   'Cruze',
#   'Epica',
#   'Evanda',
#   'Kalos',
#   'Lacetti',
#   'Malibu',
#   'Matiz',
#   'Nubira',
#   'Nubira SW',
#   'Orlando',
#   'Rezzo',
#   'Spark',
#   'Tahoe',
#   'Trans Sport',
#   'Trax',
#   'Volt',
#   'Divers'],
#  'Chrysler': ['300C',
#   '300M',
#   'Crossfire',
#   'Es',
#   'Grand Voyager',
#   'Le Baron',
#   'Neon',
#   'New Yorker',
#   'PT Cruiser',
#   'Saratoga',
#   'Sebring',
#   'Stratus',
#   'Viper',
#   'Vision',
#   'Voyager',
#   'Divers'],
#  'Citroën': [],
#  'Corvette': ['C6', 'Corvette C8', 'Z6', 'ZR1', 'Divers'],
#  'Cupra': ['Ateca', 'Born', 'Formentor', 'Leon'],
#  'DS': [],
#  'Dacia': ['Dokker',
#   'Duster',
#   'Jogger',
#   'Lodgy',
#   'Logan',
#   'Sandero',
#   'Spring',
#   'Divers'],
#  'Daewoo': ['Espero',
#   'Evanda',
#   'Feroza',
#   'Kalos',
#   'Korando',
#   'Lacetti',
#   'Lanos',
#   'Leganza',
#   'Matiz',
#   'Musso',
#   'Nexia',
#   'Nubira',
#   'Rexton',
#   'Rezzo',
#   'Divers'],
#  'Daihatsu': ['Applause',
#   'Charade',
#   'Copen',
#   'Cuore',
#   'D-Compact X-Over',
#   'Feroza',
#   'Gran Move',
#   'Materia',
#   'Move',
#   'Rocky',
#   'Sirion',
#   'Terios',
#   'Trevis',
#   'YRV',
#   'Divers'],
#  'Daimler': ['Autres'],
#  'Dangel': [],
#  'De-la-Chapelle': [],
#  'Dodge': ['Avenger',
#   'Caliber',
#   'Challenger',
#   'Charger',
#   'Journey',
#   'Nitro',
#   'RAM',
#   'Viper',
#   'Divers'],
#  'Donkervoort': [],
#  'Ferrari': ['296',
#   '308',
#   '328',
#   '348',
#   '400',
#   '412',
#   '456',
#   '458',
#   '488',
#   '575 Maranello',
#   '599',
#   '612',
#   '812',
#   'BB 512',
#   'California',
#   'F 550 Maranello',
#   'F355',
#   'F360',
#   'F430',
#   'F8 Spider',
#   'F8 Tributo',
#   'Ff',
#   'Mondial',
#   'Portofino',
#   'Roma',
#   'SF90',
#   'Testarossa'],
#  'Fiat': ['124 spider',
#   '127',
#   '500',
#   '500 C',
#   '500 E',
#   '500 L',
#   '500 X',
#   'Argenta',
#   'Barchetta',
#   'Bertone',
#   'Brava',
#   'Bravo',
#   'Cinquecento',
#   'Coupé',
#   'Croma',
#   'Croma SW',
#   'Doblo',
#   'Fiat 600',
#   'Fiorino',
#   'Freemont',
#   'Grande Punto',
#   'Idea',
#   'Marea',
#   'Multipla',
#   'Palio',
#   'Panda',
#   'Punto',
#   'QUBO',
#   'Regata',
#   'Ritmo',
#   'Sedici',
#   'Seicento',
#   'Stilo',
#   'Tempra',
#   'Tipo',
#   'Ulysse',
#   'Uno',
#   'Divers'],
#  'Ford': ['Aerostar',
#   'B-max',
#   'C-max',
#   'Cougar',
#   'Ecosport',
#   'Edge',
#   'Escort',
#   'Explorer',
#   'Fiesta',
#   'Focus',
#   'Focus C-MAX',
#   'Fusion',
#   'Galaxy',
#   'Granada',
#   'Grand C-MAX',
#   'GT',
#   'Ka',
#   'Kuga',
#   'Maverick',
#   'Mondeo',
#   'Mustang',
#   'Orion',
#   'Probe',
#   'Puma',
#   'Ranger',
#   'Scorpio',
#   'Sierra',
#   'S-MAX',
#   'Streetka',
#   'Tourneo VP',
#   'Transit',
#   'Divers'],
#  'GMC': [],
#  'Gac-Gonow': [],
#  'Honda': [],
#  'Hummer': ['H1', 'H2', 'H3'],
#  'Hyundai': ['Accent',
#   'Atos',
#   'Azera',
#   'Bayon',
#   'Coupé',
#   'Elantra',
#   'Galloper',
#   'Genesis',
#   'Getz',
#   'i10',
#   'i20',
#   'i30',
#   'i40',
#   'Ioniq',
#   'iX20',
#   'iX35',
#   'iX55',
#   'Kona',
#   'Lantra',
#   'Matrix',
#   'Nexo',
#   'Pony',
#   'Santa Fe',
#   'Satellite',
#   'Scoupe',
#   'Sonata',
#   'Terracan',
#   'Trajet',
#   'Tucson',
#   'Veloster',
#   'XG',
#   'Divers'],
#  'Infiniti': ['EX37',
#   'FX',
#   'G37',
#   'G37 Coupé',
#   'M37',
#   'Q30',
#   'Q50',
#   'Q60',
#   'Q70',
#   'QX30',
#   'Qx50',
#   'Autres'],
#  'Isuzu': ['D-MAX', 'Trooper', 'Divers'],
#  'Jaguar': ['Daimler',
#   'E-PACE',
#   'F-PACE',
#   'F-Type',
#   'I-PACE',
#   'Sovereign',
#   'S-Type',
#   'XE',
#   'XF',
#   'XJ',
#   'XJ 12',
#   'XJ 6',
#   'XJ 8',
#   'XJR',
#   'XJS',
#   'XK',
#   'XK8',
#   'XKR',
#   'X-Type',
#   'Divers'],
#  'Jeep': ['Cherokee',
#   'Commander',
#   'Compass',
#   'Grand Cherokee',
#   'Laredo',
#   'Patriot',
#   'Renegade',
#   'Willys',
#   'Wrangler',
#   'Divers'],
#  'Kia': ['Carens',
#   'Carnival',
#   'Ceed',
#   'Ceed SW',
#   'Cerato',
#   'Clarus',
#   'Cutback',
#   'EV6',
#   'Korando',
#   'Magentis',
#   'Niro',
#   'Opirus',
#   'OPTIMA',
#   'Picanto',
#   'Pride',
#   'Pro Cee d ii',
#   'Rio',
#   'Sephia',
#   'Shuma',
#   'Sorento',
#   'Soul',
#   'Sportage',
#   'Stinger',
#   'Stonic',
#   'Venga',
#   'XCeed',
#   'Divers'],
#  'Lada': ['110',
#   '111',
#   '1118',
#   '112',
#   '1500 Break',
#   'Kalina',
#   'Kalinka',
#   'Natacha',
#   'Niva',
#   'Priora',
#   'Sagona',
#   'Samara',
#   'Divers'],
#  'Lamborghini': ['Aventador',
#   'Diablo',
#   'Gallardo',
#   'Huracan',
#   'Murcielago',
#   'Urus',
#   'Divers'],
#  'Lancia': ['Beta',
#   'Dedra',
#   'Delta',
#   'Flavia',
#   'Gamma',
#   'Kappa',
#   'Lybra',
#   'Musa',
#   'Phedra',
#   'Prisma',
#   'Thema',
#   'Thesis',
#   'VOYAGER',
#   'Y10',
#   'Ypsilon',
#   'Zeta',
#   'Divers'],
#  'Land-Rover': ['Defender',
#   'Discovery',
#   'Discovery sport',
#   'Freelander',
#   'Range Rover',
#   'Range Rover Evoque',
#   'Range rover velar',
#   'Range Sport',
#   'Divers'],
#  'Landwin': [],
#  'Lexus': [],
#  'Lotus': ['Elan', 'Elise', 'Esprit', 'Evora', 'Exige', 'Divers'],
#  'MG': [],
#  'MPM-Motos': [],
#  'Mahindra': ['Bolero', 'CJ 340', 'CJ 540', 'Goa', 'Goa Pick-up', 'Divers'],
#  'Maruti': [],
#  'Maserati': ['222 Coupe',
#   '3200',
#   '430 biturbo',
#   'Coupe',
#   'Ghibli',
#   'Grancabrio',
#   'Grandsport',
#   'Granturismo',
#   'Levante',
#   'MC20',
#   'Quattroporte',
#   'Shamal',
#   'Spider cabriolet',
#   'Spyder',
#   'Divers'],
#  'Maybach': [],
#  'Mazda': ['121',
#   '323',
#   '626',
#   '929',
#   'Bt-50 Pick-up',
#   'Cx-3',
#   'CX-30',
#   'CX-5',
#   'Cx-7',
#   'Demio',
#   'Mazda2',
#   'Mazda3',
#   'Mazda5',
#   'Mazda6',
#   'MPV',
#   'MX-3',
#   'MX-30',
#   'MX-5',
#   'MX-6',
#   'Premacy',
#   'RX-7',
#   'RX-8',
#   'Tribute',
#   'Xedos',
#   'Divers'],
#  'Mega': ['Break', 'Club Berline', 'Club Cabriolet', 'Club Fourgon', 'Divers'],
#  'Mercedes': ['126',
#   '190',
#   '200',
#   '230',
#   '250',
#   '260',
#   '280',
#   '300',
#   '500',
#   '560',
#   'AMG GT',
#   'Citan',
#   'Classe A',
#   'Classe B',
#   'Classe C',
#   'Classe CL',
#   'Classe CLA',
#   'Classe CLC',
#   'Classe CLS',
#   'Classe E',
#   'Classe G',
#   'Classe GL',
#   'Classe GLA',
#   'Classe GLC',
#   'Classe GLE',
#   'Classe GLK',
#   'Classe GLS',
#   'Classe M',
#   'Classe R',
#   'Classe S',
#   'Classe V',
#   'Classe X',
#   'CLK',
#   'EQA',
#   'EQB',
#   'EQC',
#   'EQS',
#   'EQV',
#   'GLB',
#   'SL',
#   'SLC',
#   'SLK',
#   'SLR',
#   'SLS',
#   'Vaneo',
#   'Viano',
#   'Divers'],
#  'Mini': ['Clubman',
#   'Cooper',
#   'Cooper D',
#   'Cooper S',
#   'Countryman',
#   'Mini clubvan',
#   'MINI COUPE',
#   'MINI ROADSTER',
#   'One',
#   'One D',
#   'Paceman',
#   'Divers'],
#  'Mitsubishi': ['3000 GT',
#   'Asx',
#   'Carisma',
#   'Colt',
#   'Eclipse Cross',
#   'Galant',
#   'Grandis',
#   'I-Miev',
#   'L200',
#   'Lancer',
#   'Montero',
#   'Outlander',
#   'Pajero',
#   'Space Runner',
#   'Space Star',
#   'Space Wagon',
#   'Divers'],
#  'Morgan': ['Plus 4', 'Plus 8', 'Divers'],
#  'Nissan': [],
#  'Opel': ['Adam',
#   'Agila',
#   'Ampera',
#   'Antara',
#   'Ascona',
#   'Astra',
#   'Calibra',
#   'Cascada',
#   'Combo VP',
#   'Corsa',
#   'Crossland',
#   'Crossland X',
#   'Frontera',
#   'Grandland',
#   'Grandland x',
#   'GT',
#   'Insignia',
#   'Kadett',
#   'Karl',
#   'Meriva',
#   'Mokka',
#   'Monterey',
#   'Omega',
#   'Signum',
#   'Sintra',
#   'Speedster',
#   'Tigra',
#   'Vectra',
#   'Zafira',
#   'Divers'],
#  'PGO': ['180 Cévennes', 'Speedster II', 'Divers'],
#  'Peugeot': ['1007',
#   '104',
#   '106',
#   '107',
#   '108',
#   '2008',
#   '205',
#   '206',
#   '206 CC',
#   '206 SW',
#   '207',
#   '207 CC',
#   '207 SW',
#   '208',
#   '3008',
#   '301',
#   '305',
#   '306',
#   '307',
#   '307 CC',
#   '307 SW',
#   '308',
#   '308 CC',
#   '308 SW',
#   '309',
#   '4007',
#   '4008',
#   '405',
#   '406',
#   '406 Coupe',
#   '407',
#   '407 Coupe',
#   '407 SW',
#   '5008',
#   '504',
#   '505',
#   '508',
#   '508 SW',
#   '604',
#   '605',
#   '607',
#   '806',
#   '807',
#   'Bipper tepee',
#   'Expert tepee',
#   'iOn',
#   'Partner',
#   'Partner Tepee',
#   'RCZ',
#   'Rifter',
#   'Traveller',
#   'Divers'],
#  'Polski/FSO': [],
#  'Pontiac': ['Firebird', 'Grand Prix', 'TransSport', 'Divers'],
#  'Porsche': ['356',
#   '911',
#   '911 (964)',
#   '911 (991)',
#   '911 (993)',
#   '911 (996)',
#   '911 (997)',
#   '911 Carrera 3.2',
#   '911 GTS',
#   '911 SC',
#   '912',
#   '914',
#   '924',
#   '928',
#   '930 Turbo',
#   '944',
#   '959',
#   '968',
#   'Boxster',
#   'Boxster (986)',
#   'Boxster (987)',
#   'Carrera GT',
#   'Cayenne',
#   'Cayman',
#   'Macan',
#   'Panamera',
#   'Taycan',
#   'Divers'],
#  'Proton': [],
#  'Renault': ['Alpine',
#   'Arkana',
#   'Avantime',
#   'Captur',
#   'Clio',
#   'Clio II',
#   'Clio III',
#   'Clio III Estate',
#   'Clio IV',
#   'Clio IV Estate',
#   'Clio V',
#   'Espace',
#   'Express',
#   'Fluence',
#   'Grand Espace',
#   'Grand Modus',
#   'Grand Scénic II',
#   'Grand Scénic III',
#   'Grand scenic IV',
#   'Kadjar',
#   'Kangoo',
#   'Koleos',
#   'Laguna',
#   'Laguna II',
#   'Laguna II Estate',
#   'Laguna III',
#   'Laguna III Coupé',
#   'Laguna III Estate',
#   'Latitude',
#   'Mégane',
#   'Mégane Cabriolet',
#   'Mégane Classic',
#   'Mégane Coupé',
#   'Mégane II',
#   'Mégane II CC',
#   'Mégane II Coupé',
#   'Mégane II Estate',
#   'Mégane III',
#   'Mégane III CC',
#   'Mégane III Coupé',
#   'Mégane III Estate',
#   'Megane IV',
#   'Megane IV Estate',
#   'Modus',
#   'Nevada',
#   'R11',
#   'R18',
#   'R19',
#   'R20',
#   'R21',
#   'R25',
#   'R30',
#   'R4',
#   'R5',
#   'R9',
#   'Rodéo',
#   'Safrane',
#   'Scénic',
#   'Scénic II',
#   'Scénic III',
#   'Scenic IV',
#   'Scenic xmod',
#   'Spider Sport',
#   'Super 5',
#   'Talisman',
#   'Trafic',
#   'Twingo',
#   'Twingo II',
#   'Twingo III',
#   'Twizy',
#   'Vel Satis',
#   'Wind',
#   'Zoé',
#   'Divers'],
#  'Rolls-Royce': ['Corniche',
#   'Flying Spur',
#   'Ghost',
#   'Park',
#   'Phantom',
#   'Silver Dawn',
#   'Silver Seraph',
#   'Silver Spirit',
#   'Silver Spur',
#   'Touring-Limousine',
#   'Divers'],
#  'Rover': ['25',
#   '45',
#   '75',
#   'Metro',
#   'Mini',
#   'Montego',
#   'Série 100',
#   'Série 200',
#   'Série 400',
#   'Série 600',
#   'Série 800',
#   'Streetwise',
#   'Divers'],
#  'Saab': ['900', '9000', '9-3', '9-3X', '9-4X', '9-5', '9-7X', 'Divers'],
#  'Santana': ['PS 10', 'S 300/350', 'Samurai', 'Vitara', 'Divers'],
#  'Seat': ['Alhambra',
#   'Altea',
#   'Altea XL',
#   'Arona',
#   'Arosa',
#   'Ateca',
#   'Cordoba',
#   'DFSK EC 35',
#   'Exeo',
#   'Ibiza',
#   'Leon',
#   'Malaga',
#   'Marbella',
#   'Mii',
#   'Seres 3',
#   'Tarraco',
#   'Terra',
#   'Toledo',
#   'Divers'],
#  'Seres': [],
#  'Shuanghuan': [],
#  'Skoda': ['Citigo',
#   'Enyaq',
#   'Fabia',
#   'Favorit',
#   'Felicia',
#   'Kamiq',
#   'Karoq',
#   'Kodiaq',
#   'Octavia',
#   'Rapid',
#   'Roomster',
#   'Scala',
#   'Superb',
#   'Yeti',
#   'Divers'],
#  'Smart': ['ForFour', 'ForTwo', 'Roadster', 'Roadster Coupé', 'Divers'],
#  'Ssangyong': ['Actyon',
#   'Family',
#   'Korando',
#   'Kyron',
#   'Musso',
#   'Rexton',
#   'Rodius',
#   'Tivoli',
#   'Divers'],
#  'Subaru': ['B9 Tribeca',
#   'Brz',
#   'E 12',
#   'Forester',
#   'G3X Justy',
#   'Impreza',
#   'Justy',
#   'Legacy',
#   'Levorg',
#   'Outback',
#   'SVX',
#   'Trezia',
#   'Vanille',
#   'WRX',
#   'XV',
#   'Divers'],
#  'Suzuki': [],
#  'TVR': ['Cerbera', 'Chimaera', 'Griffith', 'S4', 'Divers'],
#  'Talbot': ['Samba'],
#  'Tata': [],
#  'Tesla': ['Model 3', 'Model S', 'Model X', 'Model Y'],
#  'Toyota': [],
#  'Venturi': [],
#  'Volkswagen': ['Amarok',
#   'Arteon',
#   'Beetle',
#   'Bora',
#   'Caddy',
#   'Caravelle',
#   'COCCINELLE II',
#   'Corrado',
#   'E-Golf',
#   'EOS',
#   'Fox',
#   'Golf',
#   'Golf Plus',
#   'Golf SW',
#   'ID 5',
#   'ID.3',
#   'ID.4',
#   'Jetta',
#   'Lupo',
#   'MULTIVAN',
#   'Passat',
#   'Phaeton',
#   'Polo',
#   'Scirocco',
#   'Sharan',
#   'Taigo',
#   'T-Cross',
#   'Tiguan',
#   'Tiguan Allspace',
#   'Touareg',
#   'Touran',
#   'T-ROC',
#   'UP',
#   'Vento',
#   'Divers'],
#  'Volvo': ['240',
#   '340',
#   '360',
#   '440',
#   '460',
#   '480',
#   '740',
#   '760',
#   '850',
#   '940',
#   '960',
#   'C30',
#   'C40',
#   'C70',
#   'S40',
#   'S60',
#   'S70',
#   'S80',
#   'S90',
#   'V40',
#   'V50',
#   'V60',
#   'V70',
#   'V90',
#   'XC40',
#   'XC60',
#   'XC70',
#   'XC90',
#   'Divers'],
#  'Wallys': []}

# %%
data = pd.DataFrame.from_dict(start_urls)

# %%
df = data.copy()

# %%
df.head()
# Out:
#                                                  url  status  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/da...     200
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 2  https://www.paruvendu.fr/a/voiture-occasion/ni...     200
# 3  https://www.paruvendu.fr/a/voiture-occasion/ni...     200
# 4  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
#
#                  location                                     version  \
# 0          dissay (86130)     version duster tce 130 fap 4x2 prestige
# 1         59240 dunkerque   version cooper s red hot chili 192 cv bva
# 2             53000 laval  version 1.5 dci 110ch fap ultimate edition
# 3          belley (01300)   version qashqai 1.6 dci 130 xtronic tekna
# 4  30200 bagnols-sur-cèze     version one d 95 ch edition blackfriars
#
#            price                                               year  \
# 0  prix 17 600 €  année février 2019 le comparateur d'assurance ...
# 1  prix 24 990 €  année mai 2018 le comparateur d'assurance pour...
# 2   prix 8 490 €  année octobre 2013 le comparateur d'assurance ...
# 3  prix 16 900 €  année octobre 2016 le comparateur d'assurance ...
# 4  prix 17 900 €  année février 2018 le comparateur d'assurance ...
#
#                   mileage        fuel_type                   emission  \
# 0   kilométrage 18 300 km  energie essence                        N/A
# 1   kilométrage 47 500 km  energie essence  emissions de co2 119 g/km
# 2  kilométrage 166 400 km   energie diesel  emissions de co2 129 g/km
# 3   kilométrage 61 500 km   energie diesel  emissions de co2 128 g/km
# 4   kilométrage 58 529 km   energie diesel   emissions de co2 99 g/km
#
#                                fuel_usage              transmission  \
# 0                                     N/A     transmission manuelle
# 1                                     N/A  transmission automatique
# 2                                     N/A     transmission manuelle
# 3  consommation mixte 4.9 litres / 100 km  transmission automatique
# 4                                     N/A     transmission manuelle
#
#                             door_nb          technical_power  \
# 0  nb de portes 4 portes avec hayon   puissance fiscale 7 cv
# 1  nb de portes 2 portes avec hayon  puissance fiscale 10 cv
# 2  nb de portes 4 portes avec hayon   puissance fiscale 6 cv
# 3  nb de portes 4 portes avec hayon   puissance fiscale 7 cv
# 4  nb de portes 4 portes avec hayon   puissance fiscale 5 cv
#
#                      seat_nb actual_power  body_colour body_type
# 0  nombre de places 5 places          130        blanc       4x4
# 1  nombre de places 4 places          192  rouge foncé   berline
# 2  nombre de places 5 places          110         gris     break
# 3  nombre de places 5 places          130   gris foncé       4x4
# 4  nombre de places 5 places           95         gris   berline

# %% [markdown]
# ## Pré-nettoyage

# %%
import re 
import numpy as np

# %%
def extract_data(column, index):
    url_list = df[column].tolist()
    
    brand_model_list = []
    for url in url_list:
        if 'N/A' not in url:
            url = url.split(' ')[index]
            brand_model_list.append(url)
        else:
            brand_model_list.append(url)
            
    return brand_model_list

# %%
columns = ['fuel_usage', 'technical_power']
for col in columns:
    df[col] = extract_data(col, 2)

# %%
df['year'] = df['year'].apply(lambda x: re.sub("[^\d\.]", "", f"{x}")).replace({'':np.nan})
df['year'] = df['year'].astype('string').str[:4].astype('Int64')

# %%
columns = ['emission', 'door_nb', 'seat_nb']
for col in columns:
    df[col] = extract_data(col, 3)

# %%
url_list = df['url'].tolist()
brand_model_list = []
for url in url_list:
    url = url.split('/')
    brand_model = url[5] + "/" + url[6]
    brand_model_list.append(brand_model)
df['version'] = brand_model_list

# %%
columns = ['location', 'price', 'mileage']

for col in columns:  
    df[col] = df[col].apply(lambda x: re.sub("[^\d\.]", "", f"{x}"))
    df[col] = df[col].astype('Int64', errors='ignore')

# %%
df = df.replace({"N/A": np.nan, '': np.nan})
df['fuel_type'] = df['fuel_type'].str.replace('energie ', '')
df['transmission'] = df['transmission'].str.replace('transmission ', '')
del df['url']
del df['status']
# del df['emission']
del df['fuel_usage']

# %%
df.head()
# Out:
#   location         version  price  year mileage fuel_type emission  \
# 0    86130    dacia/duster  17600  2019   18300   essence      NaN
# 1    59240     mini/cooper  24990  2018   47500   essence      119
# 2    53000  nissan/qashqai   8490  2013  166400    diesel      129
# 3    01300  nissan/qashqai  16900  2016   61500    diesel      128
# 4    30200     mini/cooper  17900  2018   58529    diesel       99
#
#   transmission door_nb technical_power seat_nb actual_power  body_colour  \
# 0     manuelle       4               7       5          130        blanc
# 1  automatique       2              10       4          192  rouge foncé
# 2     manuelle       4               6       5          110         gris
# 3  automatique       4               7       5          130   gris foncé
# 4     manuelle       4               5       5           95         gris
#
#   body_type
# 0       4x4
# 1   berline
# 2     break
# 3       4x4
# 4   berline

# %% [markdown]
# ### Enregistrement du dataframe

# %%
df.to_csv('data/paruvendu.csv', index=False, encoding="utf-8")

# %% [markdown]
# ## Phase exploratoire

# %%
df.version.value_counts()
# Out:
# citroen/ds7               233
# peugeot/3008              223
# bmw/serie-1               220
# opel/corsa                217
# nissan/juke               217
#                          ...
# benne-amovible/renault      1
# renault/scenic-ii           1
# renault/express             1
# kia/pro-cee-d-ii            1
# seat/exeo                   1
# Name: version, Length: 224, dtype: int64

# %%
df.fuel_type.value_counts()
# Out:
# diesel        7683
# essence       7473
# hybride        614
# autres         245
# electrique     130
# gpl ou gnl      18
# Name: fuel_type, dtype: int64

# %%
df.transmission.value_counts()
# Out:
# manuelle            6631
# automatique         5468
# semi automatique     592
# autres                14
# Name: transmission, dtype: int64

# %%
df.body_colour.value_counts()
# Out:
# noir                                2213
# blanc                               2167
# gris clair                          1058
# gris                                 748
# gris fonce                           543
#                                     ...
# mountain gray - metallich finish       1
# col. métallisé gris record             1
# "saphirschwarz" metallise              1
# bleu nautic                            1
# melting silver metallisée>             1
# Name: body_colour, Length: 970, dtype: int64

# %%
df.seat_nb.value_counts()
# Out:
# 5     9529
# 4     1472
# 7      333
# 2      301
# 6       23
# 3       12
# 9        9
# 8        8
# 54       1
# Name: seat_nb, dtype: int64

# %% [markdown]
# ### Création d'une colonne modèle

# %%
models = [element for key, value in brands.items() for element in value]
models
# Out:
# ['500',
#  '595',
#  '695',
#  'Abarth 124 spider',
#  'F595',
#  'Grande Punto',
#  '2141',
#  'Divers',
#  'B10',
#  'B12',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'D4',
#  'Xd3',
#  'Divers',
#  'Aro 10',
#  'Aro 24',
#  'Cross Lander',
#  'Forester',
#  'Pick-up',
#  'Spartana',
#  'Trapeurs',
#  'Divers',
#  '100',
#  '200',
#  '80',
#  '90',
#  'A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'Allroad',
#  'Coupé',
#  'E-TRON',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q7',
#  'Q8',
#  'R8',
#  'RS Q3',
#  'RS3',
#  'RS4',
#  'RS5',
#  'RS6',
#  'S3',
#  'S4',
#  'S5',
#  'S6',
#  'S8',
#  'SQ5',
#  'SQ7',
#  'SQ8',
#  'TT',
#  'TT S',
#  'V8',
#  'Divers',
#  'Autres',
#  'Mini',
#  'A3',
#  'A4',
#  'Divers',
#  'i3',
#  'i4',
#  'i8',
#  'iX',
#  'iX3',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'Série 1',
#  'Serie 2',
#  'Série 3',
#  'Série 4',
#  'Série 5',
#  'Série 6',
#  'Série 7',
#  'Série 8',
#  'X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'Z1',
#  'Z3',
#  'Z4',
#  'Z8',
#  'Divers',
#  'Free Climber',
#  'Autres',
#  'Baboulin',
#  'DuneBuggy',
#  'LM1',
#  'Park Avenue',
#  'Divers',
#  'Allante',
#  'ATS',
#  'BLS',
#  'CTS',
#  'Eldorado',
#  'Escalade',
#  'Fleetwood',
#  'Seville',
#  'SRX',
#  'STS',
#  'XLR',
#  'Divers',
#  'Alero',
#  'Aveo',
#  'Beretta',
#  'Blazer',
#  'Camaro',
#  'Captiva',
#  'Corsica',
#  'Corvette',
#  'Cruze',
#  'Epica',
#  'Evanda',
#  'Kalos',
#  'Lacetti',
#  'Malibu',
#  'Matiz',
#  'Nubira',
#  'Nubira SW',
#  'Orlando',
#  'Rezzo',
#  'Spark',
#  'Tahoe',
#  'Trans Sport',
#  'Trax',
#  'Volt',
#  'Divers',
#  '300C',
#  '300M',
#  'Crossfire',
#  'Es',
#  'Grand Voyager',
#  'Le Baron',
#  'Neon',
#  'New Yorker',
#  'PT Cruiser',
#  'Saratoga',
#  'Sebring',
#  'Stratus',
#  'Viper',
#  'Vision',
#  'Voyager',
#  'Divers',
#  'C6',
#  'Corvette C8',
#  'Z6',
#  'ZR1',
#  'Divers',
#  'Ateca',
#  'Born',
#  'Formentor',
#  'Leon',
#  'Dokker',
#  'Duster',
#  'Jogger',
#  'Lodgy',
#  'Logan',
#  'Sandero',
#  'Spring',
#  'Divers',
#  'Espero',
#  'Evanda',
#  'Feroza',
#  'Kalos',
#  'Korando',
#  'Lacetti',
#  'Lanos',
#  'Leganza',
#  'Matiz',
#  'Musso',
#  'Nexia',
#  'Nubira',
#  'Rexton',
#  'Rezzo',
#  'Divers',
#  'Applause',
#  'Charade',
#  'Copen',
#  'Cuore',
#  'D-Compact X-Over',
#  'Feroza',
#  'Gran Move',
#  'Materia',
#  'Move',
#  'Rocky',
#  'Sirion',
#  'Terios',
#  'Trevis',
#  'YRV',
#  'Divers',
#  'Autres',
#  'Avenger',
#  'Caliber',
#  'Challenger',
#  'Charger',
#  'Journey',
#  'Nitro',
#  'RAM',
#  'Viper',
#  'Divers',
#  '296',
#  '308',
#  '328',
#  '348',
#  '400',
#  '412',
#  '456',
#  '458',
#  '488',
#  '575 Maranello',
#  '599',
#  '612',
#  '812',
#  'BB 512',
#  'California',
#  'F 550 Maranello',
#  'F355',
#  'F360',
#  'F430',
#  'F8 Spider',
#  'F8 Tributo',
#  'Ff',
#  'Mondial',
#  'Portofino',
#  'Roma',
#  'SF90',
#  'Testarossa',
#  '124 spider',
#  '127',
#  '500',
#  '500 C',
#  '500 E',
#  '500 L',
#  '500 X',
#  'Argenta',
#  'Barchetta',
#  'Bertone',
#  'Brava',
#  'Bravo',
#  'Cinquecento',
#  'Coupé',
#  'Croma',
#  'Croma SW',
#  'Doblo',
#  'Fiat 600',
#  'Fiorino',
#  'Freemont',
#  'Grande Punto',
#  'Idea',
#  'Marea',
#  'Multipla',
#  'Palio',
#  'Panda',
#  'Punto',
#  'QUBO',
#  'Regata',
#  'Ritmo',
#  'Sedici',
#  'Seicento',
#  'Stilo',
#  'Tempra',
#  'Tipo',
#  'Ulysse',
#  'Uno',
#  'Divers',
#  'Aerostar',
#  'B-max',
#  'C-max',
#  'Cougar',
#  'Ecosport',
#  'Edge',
#  'Escort',
#  'Explorer',
#  'Fiesta',
#  'Focus',
#  'Focus C-MAX',
#  'Fusion',
#  'Galaxy',
#  'Granada',
#  'Grand C-MAX',
#  'GT',
#  'Ka',
#  'Kuga',
#  'Maverick',
#  'Mondeo',
#  'Mustang',
#  'Orion',
#  'Probe',
#  'Puma',
#  'Ranger',
#  'Scorpio',
#  'Sierra',
#  'S-MAX',
#  'Streetka',
#  'Tourneo VP',
#  'Transit',
#  'Divers',
#  'H1',
#  'H2',
#  'H3',
#  'Accent',
#  'Atos',
#  'Azera',
#  'Bayon',
#  'Coupé',
#  'Elantra',
#  'Galloper',
#  'Genesis',
#  'Getz',
#  'i10',
#  'i20',
#  'i30',
#  'i40',
#  'Ioniq',
#  'iX20',
#  'iX35',
#  'iX55',
#  'Kona',
#  'Lantra',
#  'Matrix',
#  'Nexo',
#  'Pony',
#  'Santa Fe',
#  'Satellite',
#  'Scoupe',
#  'Sonata',
#  'Terracan',
#  'Trajet',
#  'Tucson',
#  'Veloster',
#  'XG',
#  'Divers',
#  'EX37',
#  'FX',
#  'G37',
#  'G37 Coupé',
#  'M37',
#  'Q30',
#  'Q50',
#  'Q60',
#  'Q70',
#  'QX30',
#  'Qx50',
#  'Autres',
#  'D-MAX',
#  'Trooper',
#  'Divers',
#  'Daimler',
#  'E-PACE',
#  'F-PACE',
#  'F-Type',
#  'I-PACE',
#  'Sovereign',
#  'S-Type',
#  'XE',
#  'XF',
#  'XJ',
#  'XJ 12',
#  'XJ 6',
#  'XJ 8',
#  'XJR',
#  'XJS',
#  'XK',
#  'XK8',
#  'XKR',
#  'X-Type',
#  'Divers',
#  'Cherokee',
#  'Commander',
#  'Compass',
#  'Grand Cherokee',
#  'Laredo',
#  'Patriot',
#  'Renegade',
#  'Willys',
#  'Wrangler',
#  'Divers',
#  'Carens',
#  'Carnival',
#  'Ceed',
#  'Ceed SW',
#  'Cerato',
#  'Clarus',
#  'Cutback',
#  'EV6',
#  'Korando',
#  'Magentis',
#  'Niro',
#  'Opirus',
#  'OPTIMA',
#  'Picanto',
#  'Pride',
#  'Pro Cee d ii',
#  'Rio',
#  'Sephia',
#  'Shuma',
#  'Sorento',
#  'Soul',
#  'Sportage',
#  'Stinger',
#  'Stonic',
#  'Venga',
#  'XCeed',
#  'Divers',
#  '110',
#  '111',
#  '1118',
#  '112',
#  '1500 Break',
#  'Kalina',
#  'Kalinka',
#  'Natacha',
#  'Niva',
#  'Priora',
#  'Sagona',
#  'Samara',
#  'Divers',
#  'Aventador',
#  'Diablo',
#  'Gallardo',
#  'Huracan',
#  'Murcielago',
#  'Urus',
#  'Divers',
#  'Beta',
#  'Dedra',
#  'Delta',
#  'Flavia',
#  'Gamma',
#  'Kappa',
#  'Lybra',
#  'Musa',
#  'Phedra',
#  'Prisma',
#  'Thema',
#  'Thesis',
#  'VOYAGER',
#  'Y10',
#  'Ypsilon',
#  'Zeta',
#  'Divers',
#  'Defender',
#  'Discovery',
#  'Discovery sport',
#  'Freelander',
#  'Range Rover',
#  'Range Rover Evoque',
#  'Range rover velar',
#  'Range Sport',
#  'Divers',
#  'Elan',
#  'Elise',
#  'Esprit',
#  'Evora',
#  'Exige',
#  'Divers',
#  'Bolero',
#  'CJ 340',
#  'CJ 540',
#  'Goa',
#  'Goa Pick-up',
#  'Divers',
#  '222 Coupe',
#  '3200',
#  '430 biturbo',
#  'Coupe',
#  'Ghibli',
#  'Grancabrio',
#  'Grandsport',
#  'Granturismo',
#  'Levante',
#  'MC20',
#  'Quattroporte',
#  'Shamal',
#  'Spider cabriolet',
#  'Spyder',
#  'Divers',
#  '121',
#  '323',
#  '626',
#  '929',
#  'Bt-50 Pick-up',
#  'Cx-3',
#  'CX-30',
#  'CX-5',
#  'Cx-7',
#  'Demio',
#  'Mazda2',
#  'Mazda3',
#  'Mazda5',
#  'Mazda6',
#  'MPV',
#  'MX-3',
#  'MX-30',
#  'MX-5',
#  'MX-6',
#  'Premacy',
#  'RX-7',
#  'RX-8',
#  'Tribute',
#  'Xedos',
#  'Divers',
#  'Break',
#  'Club Berline',
#  'Club Cabriolet',
#  'Club Fourgon',
#  'Divers',
#  '126',
#  '190',
#  '200',
#  '230',
#  '250',
#  '260',
#  '280',
#  '300',
#  '500',
#  '560',
#  'AMG GT',
#  'Citan',
#  'Classe A',
#  'Classe B',
#  'Classe C',
#  'Classe CL',
#  'Classe CLA',
#  'Classe CLC',
#  'Classe CLS',
#  'Classe E',
#  'Classe G',
#  'Classe GL',
#  'Classe GLA',
#  'Classe GLC',
#  'Classe GLE',
#  'Classe GLK',
#  'Classe GLS',
#  'Classe M',
#  'Classe R',
#  'Classe S',
#  'Classe V',
#  'Classe X',
#  'CLK',
#  'EQA',
#  'EQB',
#  'EQC',
#  'EQS',
#  'EQV',
#  'GLB',
#  'SL',
#  'SLC',
#  'SLK',
#  'SLR',
#  'SLS',
#  'Vaneo',
#  'Viano',
#  'Divers',
#  'Clubman',
#  'Cooper',
#  'Cooper D',
#  'Cooper S',
#  'Countryman',
#  'Mini clubvan',
#  'MINI COUPE',
#  'MINI ROADSTER',
#  'One',
#  'One D',
#  'Paceman',
#  'Divers',
#  '3000 GT',
#  'Asx',
#  'Carisma',
#  'Colt',
#  'Eclipse Cross',
#  'Galant',
#  'Grandis',
#  'I-Miev',
#  'L200',
#  'Lancer',
#  'Montero',
#  'Outlander',
#  'Pajero',
#  'Space Runner',
#  'Space Star',
#  'Space Wagon',
#  'Divers',
#  'Plus 4',
#  'Plus 8',
#  'Divers',
#  'Adam',
#  'Agila',
#  'Ampera',
#  'Antara',
#  'Ascona',
#  'Astra',
#  'Calibra',
#  'Cascada',
#  'Combo VP',
#  'Corsa',
#  'Crossland',
#  'Crossland X',
#  'Frontera',
#  'Grandland',
#  'Grandland x',
#  'GT',
#  'Insignia',
#  'Kadett',
#  'Karl',
#  'Meriva',
#  'Mokka',
#  'Monterey',
#  'Omega',
#  'Signum',
#  'Sintra',
#  'Speedster',
#  'Tigra',
#  'Vectra',
#  'Zafira',
#  'Divers',
#  '180 Cévennes',
#  'Speedster II',
#  'Divers',
#  '1007',
#  '104',
#  '106',
#  '107',
#  '108',
#  '2008',
#  '205',
#  '206',
#  '206 CC',
#  '206 SW',
#  '207',
#  '207 CC',
#  '207 SW',
#  '208',
#  '3008',
#  '301',
#  '305',
#  '306',
#  '307',
#  '307 CC',
#  '307 SW',
#  '308',
#  '308 CC',
#  '308 SW',
#  '309',
#  '4007',
#  '4008',
#  '405',
#  '406',
#  '406 Coupe',
#  '407',
#  '407 Coupe',
#  '407 SW',
#  '5008',
#  '504',
#  '505',
#  '508',
#  '508 SW',
#  '604',
#  '605',
#  '607',
#  '806',
#  '807',
#  'Bipper tepee',
#  'Expert tepee',
#  'iOn',
#  'Partner',
#  'Partner Tepee',
#  'RCZ',
#  'Rifter',
#  'Traveller',
#  'Divers',
#  'Firebird',
#  'Grand Prix',
#  'TransSport',
#  'Divers',
#  '356',
#  '911',
#  '911 (964)',
#  '911 (991)',
#  '911 (993)',
#  '911 (996)',
#  '911 (997)',
#  '911 Carrera 3.2',
#  '911 GTS',
#  '911 SC',
#  '912',
#  '914',
#  '924',
#  '928',
#  '930 Turbo',
#  '944',
#  '959',
#  '968',
#  'Boxster',
#  'Boxster (986)',
#  'Boxster (987)',
#  'Carrera GT',
#  'Cayenne',
#  'Cayman',
#  'Macan',
#  'Panamera',
#  'Taycan',
#  'Divers',
#  'Alpine',
#  'Arkana',
#  'Avantime',
#  'Captur',
#  'Clio',
#  'Clio II',
#  'Clio III',
#  'Clio III Estate',
#  'Clio IV',
#  'Clio IV Estate',
#  'Clio V',
#  'Espace',
#  'Express',
#  'Fluence',
#  'Grand Espace',
#  'Grand Modus',
#  'Grand Scénic II',
#  'Grand Scénic III',
#  'Grand scenic IV',
#  'Kadjar',
#  'Kangoo',
#  'Koleos',
#  'Laguna',
#  'Laguna II',
#  'Laguna II Estate',
#  'Laguna III',
#  'Laguna III Coupé',
#  'Laguna III Estate',
#  'Latitude',
#  'Mégane',
#  'Mégane Cabriolet',
#  'Mégane Classic',
#  'Mégane Coupé',
#  'Mégane II',
#  'Mégane II CC',
#  'Mégane II Coupé',
#  'Mégane II Estate',
#  'Mégane III',
#  'Mégane III CC',
#  'Mégane III Coupé',
#  'Mégane III Estate',
#  'Megane IV',
#  'Megane IV Estate',
#  'Modus',
#  'Nevada',
#  'R11',
#  'R18',
#  'R19',
#  'R20',
#  'R21',
#  'R25',
#  'R30',
#  'R4',
#  'R5',
#  'R9',
#  'Rodéo',
#  'Safrane',
#  'Scénic',
#  'Scénic II',
#  'Scénic III',
#  'Scenic IV',
#  'Scenic xmod',
#  'Spider Sport',
#  'Super 5',
#  'Talisman',
#  'Trafic',
#  'Twingo',
#  'Twingo II',
#  'Twingo III',
#  'Twizy',
#  'Vel Satis',
#  'Wind',
#  'Zoé',
#  'Divers',
#  'Corniche',
#  'Flying Spur',
#  'Ghost',
#  'Park',
#  'Phantom',
#  'Silver Dawn',
#  'Silver Seraph',
#  'Silver Spirit',
#  'Silver Spur',
#  'Touring-Limousine',
#  'Divers',
#  '25',
#  '45',
#  '75',
#  'Metro',
#  'Mini',
#  'Montego',
#  'Série 100',
#  'Série 200',
#  'Série 400',
#  'Série 600',
#  'Série 800',
#  'Streetwise',
#  'Divers',
#  '900',
#  '9000',
#  '9-3',
#  '9-3X',
#  '9-4X',
#  '9-5',
#  '9-7X',
#  'Divers',
#  'PS 10',
#  'S 300/350',
#  'Samurai',
#  'Vitara',
#  'Divers',
#  'Alhambra',
#  'Altea',
#  'Altea XL',
#  'Arona',
#  'Arosa',
#  'Ateca',
#  'Cordoba',
#  'DFSK EC 35',
#  'Exeo',
#  'Ibiza',
#  'Leon',
#  'Malaga',
#  'Marbella',
#  'Mii',
#  'Seres 3',
#  'Tarraco',
#  'Terra',
#  'Toledo',
#  'Divers',
#  'Citigo',
#  'Enyaq',
#  'Fabia',
#  'Favorit',
#  'Felicia',
#  'Kamiq',
#  'Karoq',
#  'Kodiaq',
#  'Octavia',
#  'Rapid',
#  'Roomster',
#  'Scala',
#  'Superb',
#  'Yeti',
#  'Divers',
#  'ForFour',
#  'ForTwo',
#  'Roadster',
#  'Roadster Coupé',
#  'Divers',
#  'Actyon',
#  'Family',
#  'Korando',
#  'Kyron',
#  'Musso',
#  'Rexton',
#  'Rodius',
#  'Tivoli',
#  'Divers',
#  'B9 Tribeca',
#  'Brz',
#  'E 12',
#  'Forester',
#  'G3X Justy',
#  'Impreza',
#  'Justy',
#  'Legacy',
#  'Levorg',
#  'Outback',
#  'SVX',
#  'Trezia',
#  'Vanille',
#  'WRX',
#  'XV',
#  'Divers',
#  'Cerbera',
#  'Chimaera',
#  'Griffith',
#  'S4',
#  'Divers',
#  'Samba',
#  'Model 3',
#  'Model S',
#  'Model X',
#  'Model Y',
#  'Amarok',
#  'Arteon',
#  'Beetle',
#  'Bora',
#  'Caddy',
#  'Caravelle',
#  'COCCINELLE II',
#  'Corrado',
#  'E-Golf',
#  'EOS',
#  'Fox',
#  'Golf',
#  'Golf Plus',
#  'Golf SW',
#  'ID 5',
#  'ID.3',
#  'ID.4',
#  'Jetta',
#  'Lupo',
#  'MULTIVAN',
#  'Passat',
#  'Phaeton',
#  'Polo',
#  'Scirocco',
#  'Sharan',
#  'Taigo',
#  'T-Cross',
#  'Tiguan',
#  'Tiguan Allspace',
#  'Touareg',
#  'Touran',
#  'T-ROC',
#  'UP',
#  'Vento',
#  'Divers',
#  '240',
#  '340',
#  '360',
#  '440',
#  '460',
#  '480',
#  '740',
#  '760',
#  '850',
#  '940',
#  '960',
#  'C30',
#  'C40',
#  'C70',
#  'S40',
#  'S60',
#  'S70',
#  'S80',
#  'S90',
#  'V40',
#  'V50',
#  'V60',
#  'V70',
#  'V90',
#  'XC40',
#  'XC60',
#  'XC70',
#  'XC90',
#  'Divers']

# %%
# for element in df['version']:
#     for model in models:
#         try:
#             model = int(model)
#         except:
#             model = str(model)
#             if model in element:
#                 print(f'{element}, {model.lower()}')

# %% [markdown]
# ## Analyse de la forme des données

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.head()
# Out:
#   location         version  price  year mileage fuel_type emission  \
# 0    86130    dacia/duster  17600  2019   18300   essence      NaN
# 1    59240     mini/cooper  24990  2018   47500   essence      119
# 2    53000  nissan/qashqai   8490  2013  166400    diesel      129
# 3    01300  nissan/qashqai  16900  2016   61500    diesel      128
# 4    30200     mini/cooper  17900  2018   58529    diesel       99
#
#   transmission door_nb technical_power seat_nb actual_power  body_colour  \
# 0     manuelle       4               7       5          130        blanc
# 1  automatique       2              10       4          192  rouge foncé
# 2     manuelle       4               6       5          110         gris
# 3  automatique       4               7       5          130   gris foncé
# 4     manuelle       4               5       5           95         gris
#
#   body_type
# 0       4x4
# 1   berline
# 2     break
# 3       4x4
# 4   berline

# %%
df.shape
# Out:
# (17231, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17231 entries, 0 to 17230
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   location         17212 non-null  object
#  1   version          17231 non-null  object
#  2   price            17221 non-null  object
#  3   year             17212 non-null  Int64
#  4   mileage          17221 non-null  object
#  5   fuel_type        16163 non-null  object
#  6   emission         9957 non-null   object
#  7   transmission     12705 non-null  object
#  8   door_nb          16746 non-null  object
#  9   technical_power  16404 non-null  object
#  10  seat_nb          11688 non-null  object
#  11  actual_power     8669 non-null   object
#  12  body_colour      12344 non-null  object
#  13  body_type        14823 non-null  object
# dtypes: Int64(1), object(13)
# memory usage: 1.9+ MB

# %%
df.dtypes.value_counts()
# Out:
# object    13
# Int64      1
# dtype: int64

# %%
df.describe()
# Out:
#                year
# count  17212.000000
# mean    2017.334302
# std       45.775558
# min        3.000000
# 25%     2016.000000
# 50%     2018.000000
# 75%     2020.000000
# max     7650.000000

# %%
df.isna().sum()
# Out:
# location             19
# version               0
# price                10
# year                 19
# mileage              10
# fuel_type          1068
# emission           7274
# transmission       4526
# door_nb             485
# technical_power     827
# seat_nb            5543
# actual_power       8562
# body_colour        4887
# body_type          2408
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# actual_power       0.496895
# emission           0.422146
# seat_nb            0.321688
# body_colour        0.283617
# transmission       0.262666
# body_type          0.139748
# fuel_type          0.061981
# technical_power    0.047995
# door_nb            0.028147
# year               0.001103
# location           0.001103
# mileage            0.000580
# price              0.000580
# version            0.000000
# dtype: float64

# %% [markdown]
# ## Analyse du Fond
# ### Examen de la colonne target

# %%
df.head()
# Out:
#   location         version  price  year mileage fuel_type emission  \
# 0    86130    dacia/duster  17600  2019   18300   essence      NaN
# 1    59240     mini/cooper  24990  2018   47500   essence      119
# 2    53000  nissan/qashqai   8490  2013  166400    diesel      129
# 3    01300  nissan/qashqai  16900  2016   61500    diesel      128
# 4    30200     mini/cooper  17900  2018   58529    diesel       99
#
#   transmission door_nb technical_power seat_nb actual_power  body_colour  \
# 0     manuelle       4               7       5          130        blanc
# 1  automatique       2              10       4          192  rouge foncé
# 2     manuelle       4               6       5          110         gris
# 3  automatique       4               7       5          130   gris foncé
# 4     manuelle       4               5       5           95         gris
#
#   body_type
# 0       4x4
# 1   berline
# 2     break
# 3       4x4
# 4   berline

# %%
df['price'].describe()
# Out:
# count     17221
# unique     2667
# top       11990
# freq        214
# Name: price, dtype: object

# %%
df['version'].value_counts(normalize=True)
# Out:
# citroen/ds7               0.013522
# peugeot/3008              0.012942
# bmw/serie-1               0.012768
# opel/corsa                0.012594
# nissan/juke               0.012594
#                             ...
# benne-amovible/renault    0.000058
# renault/scenic-ii         0.000058
# renault/express           0.000058
# kia/pro-cee-d-ii          0.000058
# seat/exeo                 0.000058
# Name: version, Length: 224, dtype: float64

# %%
# # Some data
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# fracs = [15, 30, 45, 10]

# # Make figure and axes
# fig, axs = plt.subplots(1, 2)

# # A standard pie plot
# axs[0].pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)

# # Shift the second slice using explode
# axs[1].pie(fracs, labels=labels, autopct='%.0f%%', shadow=True,
#               explode=(0, 0.1, 0, 0))

# plt.show()

# %%
df['version'].value_counts()
# Out:
# citroen/ds7               233
# peugeot/3008              223
# bmw/serie-1               220
# opel/corsa                217
# nissan/juke               217
#                          ...
# benne-amovible/renault      1
# renault/scenic-ii           1
# renault/express             1
# kia/pro-cee-d-ii            1
# seat/exeo                   1
# Name: version, Length: 224, dtype: int64

# %%
df['body_colour'].value_counts()
# Out:
# noir                                2213
# blanc                               2167
# gris clair                          1058
# gris                                 748
# gris fonce                           543
#                                     ...
# mountain gray - metallich finish       1
# col. métallisé gris record             1
# "saphirschwarz" metallise              1
# bleu nautic                            1
# melting silver metallisée>             1
# Name: body_colour, Length: 970, dtype: int64

# %%
df['year'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df['fuel_type'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='fuel_type'>

# %%
# df.groupby('fuel_type')['price'].mean().plot.pie()

# %%
df['transmission'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='transmission'>

# %%
# df.groupby('transmission')['price'].mean().plot.pie()

# %% [markdown]
# ### Histogrames des variables continues

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
df_float = df[columns].astype('float64', errors='ignore').iloc[:, 1:]
for col in df_float.select_dtypes('float64'):
    plt.figure(figsize=(10,4))
    sns.histplot(df_float[col], kde=True, stat='density')

# %% [markdown]
# ### Relation Variables / Variables

# %%
sns.pairplot(df)

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16,10))
mask = np.triu(np.ones_like(corrmat, dtype=np.bool))
sns.heatmap(corrmat, mask=mask, vmax=.8, square=True, cbar=True, annot=True, fmt='.3f', annot_kws={'size': 10});
ax.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':14}, pad=16)

# %%
#correlation matrix
corrmat = df.corr()
sns.clustermap(corrmat, fmt='.1f');
ax.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':14}, pad=16)

# %%
df_scatter = df.copy()
df_scatter = df_scatter.dropna()

# %%
plt.rcParams["figure.figsize"] = (16,8)
df_scatter.plot.scatter(x = 'year', y = 'price')

# %%
plt.rcParams["figure.figsize"] = (16,8)
df_scatter.plot.scatter(x = 'mileage', y = 'price')
