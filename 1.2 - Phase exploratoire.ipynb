# %%
import pandas as pd
import json

# %%
data_01 = pd.read_csv("data/data_paruvendu01.csv")
data_02 = pd.read_csv("data/data_paruvendu02.csv")
data = pd.concat([data_01, data_02]).reset_index(drop=True).reset_index()
data
# Out:
#        index                                        Version      Prix  \
# 0          0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1          1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2          2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3          3                                            NaN       NaN
# 4          4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
# ...      ...                                            ...       ...
# 15738  15738                         2.0L SKYACTIV-G 160 ch  26 400 €
# 15739  15739         CX-3 2.0L Skyactiv-G 120 4x2 Dynamique  14 700 €
# 15740  15740                        1.6 110CH ELEGANCE PACK   9 990 €
# 15741  15741      2021 2.0L E-SKYACTIV X 186CH BA6 SPORTINE  32 900 €
# 15742  15742                                            NaN  19 490 €
#
#                 Année Kilométrage  Energie  Emissions de CO2  \
# 0        Octobre 2018      30 400  Essence             139.0
# 1            Mai 2011      66 100  Essence             142.0
# 2           Mars 2015     129 000  Essence             150.0
# 3                 NaN         NaN      NaN               NaN
# 4            Mai 2019      66 530  Essence             153.0
# ...               ...         ...      ...               ...
# 15738  Septembre 2017      41 000  Essence             154.0
# 15739    Février 2018      52 045  Essence             137.0
# 15740       Juin 2002     125 882  Essence             196.0
# 15741   Décembre 2021         500  Hybride               NaN
# 15742   Décembre 2019      16 461  Essence               NaN
#
#        Consommation mixte      Transmission         Nb de portes  ...  \
# 0                     6.0          Manuelle  2 portes avec hayon  ...
# 1                     6.0          Manuelle  2 portes avec hayon  ...
# 2                     6.5  Semi automatique  2 portes avec hayon  ...
# 3                     NaN               NaN                  NaN  ...
# 4                     NaN          Manuelle  2 portes avec hayon  ...
# ...                   ...               ...                  ...  ...
# 15738                 NaN          Manuelle  2 portes avec hayon  ...
# 15739                 5.9          Manuelle  4 portes avec hayon  ...
# 15740                 NaN          Manuelle             2 portes  ...
# 15741                 NaN       Automatique  4 portes avec hayon  ...
# 15742                 NaN          Manuelle  4 portes avec hayon  ...
#
#                      Autres informations  Garantie mécanique  \
# 0                                    NaN                 NaN
# 1      Première main,Véhicule non fumeur                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    NaN                 NaN
# ...                                  ...                 ...
# 15738                                NaN                 NaN
# 15739                                NaN                 NaN
# 15740                                NaN             12 mois
# 15741                                NaN                 NaN
# 15742                                NaN                 NaN
#
#       Vignette CritAir Couleur intérieur  Type de peinture carrosserie  \
# 0                   NaN               NaN                           NaN
# 1                   NaN               NaN                           NaN
# 2                   NaN               NaN                           NaN
# 3                   NaN               NaN                           NaN
# 4                   NaN               NaN                           NaN
# ...                 ...               ...                           ...
# 15738               NaN               NaN                           NaN
# 15739               NaN               NaN                           NaN
# 15740               NaN               NaN                           NaN
# 15741               NaN               NaN                           NaN
# 15742               NaN               NaN                           NaN
#
#       Contrôle technique Etat du véhicule  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# ...                  ...              ...
# 15738                NaN              NaN
# 15739                NaN              NaN
# 15740                NaN              NaN
# 15741                NaN              NaN
# 15742                NaN              NaN
#
#        Option/Equipement Confort intérieur Option/equipement extérieurs  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 15738                                  NaN                          NaN
# 15739                                  NaN                          NaN
# 15740                                  NaN                          NaN
# 15741                                  NaN                          NaN
# 15742                                  NaN                          NaN
#
#       Option equipement Sécurité
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 15738                        NaN
# 15739                        NaN
# 15740                        NaN
# 15741                        NaN
# 15742                        NaN
#
# [15743 rows x 25 columns]

# %%
start_urls = []
with open('data/harvest1.json','r') as sample:
    for line in sample:
        start_urls.append(json.loads(line.strip()))

# %%
dict_of_values = {}
brand = [value.split('/')[5] for element in start_urls for key, value in element.items()]
model = [value.split('/')[6] for element in start_urls for key, value in element.items()]

dict_of_values['brand'] = brand
dict_of_values['model'] = model

# %%
data_brand = pd.DataFrame(dict_of_values)[:15743].reset_index()

# %%
data.merge(data_brand)
# Out:
#        index                                        Version      Prix  \
# 0          0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1          1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2          2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3          3                                            NaN       NaN
# 4          4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
# ...      ...                                            ...       ...
# 15738  15738                         2.0L SKYACTIV-G 160 ch  26 400 €
# 15739  15739         CX-3 2.0L Skyactiv-G 120 4x2 Dynamique  14 700 €
# 15740  15740                        1.6 110CH ELEGANCE PACK   9 990 €
# 15741  15741      2021 2.0L E-SKYACTIV X 186CH BA6 SPORTINE  32 900 €
# 15742  15742                                            NaN  19 490 €
#
#                 Année Kilométrage  Energie  Emissions de CO2  \
# 0        Octobre 2018      30 400  Essence             139.0
# 1            Mai 2011      66 100  Essence             142.0
# 2           Mars 2015     129 000  Essence             150.0
# 3                 NaN         NaN      NaN               NaN
# 4            Mai 2019      66 530  Essence             153.0
# ...               ...         ...      ...               ...
# 15738  Septembre 2017      41 000  Essence             154.0
# 15739    Février 2018      52 045  Essence             137.0
# 15740       Juin 2002     125 882  Essence             196.0
# 15741   Décembre 2021         500  Hybride               NaN
# 15742   Décembre 2019      16 461  Essence               NaN
#
#        Consommation mixte      Transmission         Nb de portes  ...  \
# 0                     6.0          Manuelle  2 portes avec hayon  ...
# 1                     6.0          Manuelle  2 portes avec hayon  ...
# 2                     6.5  Semi automatique  2 portes avec hayon  ...
# 3                     NaN               NaN                  NaN  ...
# 4                     NaN          Manuelle  2 portes avec hayon  ...
# ...                   ...               ...                  ...  ...
# 15738                 NaN          Manuelle  2 portes avec hayon  ...
# 15739                 5.9          Manuelle  4 portes avec hayon  ...
# 15740                 NaN          Manuelle             2 portes  ...
# 15741                 NaN       Automatique  4 portes avec hayon  ...
# 15742                 NaN          Manuelle  4 portes avec hayon  ...
#
#        Vignette CritAir  Couleur intérieur Type de peinture carrosserie  \
# 0                    NaN                NaN                          NaN
# 1                    NaN                NaN                          NaN
# 2                    NaN                NaN                          NaN
# 3                    NaN                NaN                          NaN
# 4                    NaN                NaN                          NaN
# ...                  ...                ...                          ...
# 15738                NaN                NaN                          NaN
# 15739                NaN                NaN                          NaN
# 15740                NaN                NaN                          NaN
# 15741                NaN                NaN                          NaN
# 15742                NaN                NaN                          NaN
#
#       Contrôle technique  Etat du véhicule  \
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
# ...                  ...               ...
# 15738                NaN               NaN
# 15739                NaN               NaN
# 15740                NaN               NaN
# 15741                NaN               NaN
# 15742                NaN               NaN
#
#       Option/Equipement Confort intérieur Option/equipement extérieurs  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ...                                   ...                          ...
# 15738                                 NaN                          NaN
# 15739                                 NaN                          NaN
# 15740                                 NaN                          NaN
# 15741                                 NaN                          NaN
# 15742                                 NaN                          NaN
#
#        Option equipement Sécurité   brand              model
# 0                             NaN  abarth                595
# 1                             NaN  abarth       grande-punto
# 2                             NaN  abarth                595
# 3                             NaN  abarth  abarth-124-spider
# 4                             NaN  abarth                500
# ...                           ...     ...                ...
# 15738                         NaN   mazda               mx-5
# 15739                         NaN   mazda               cx-3
# 15740                         NaN   mazda               mx-5
# 15741                         NaN   mazda              cx-30
# 15742                         NaN   mazda               cx-3
#
# [15743 rows x 27 columns]

# %%
df = data.copy()

# %%
df.head()
# Out:
#    index                                        Version      Prix  \
# 0      0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1      1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2      2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3      3                                            NaN       NaN
# 4      4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
#
#           Année Kilométrage  Energie  Emissions de CO2  Consommation mixte  \
# 0  Octobre 2018      30 400  Essence             139.0                 6.0
# 1      Mai 2011      66 100  Essence             142.0                 6.0
# 2     Mars 2015     129 000  Essence             150.0                 6.5
# 3           NaN         NaN      NaN               NaN                 NaN
# 4      Mai 2019      66 530  Essence             153.0                 NaN
#
#        Transmission         Nb de portes  ...  \
# 0          Manuelle  2 portes avec hayon  ...
# 1          Manuelle  2 portes avec hayon  ...
# 2  Semi automatique  2 portes avec hayon  ...
# 3               NaN                  NaN  ...
# 4          Manuelle  2 portes avec hayon  ...
#
#                  Autres informations  Garantie mécanique Vignette CritAir  \
# 0                                NaN                 NaN               NaN
# 1  Première main,Véhicule non fumeur                 NaN               NaN
# 2                                NaN                 NaN               NaN
# 3                                NaN                 NaN               NaN
# 4                                NaN                 NaN               NaN
#
#   Couleur intérieur  Type de peinture carrosserie Contrôle technique  \
# 0               NaN                           NaN                NaN
# 1               NaN                           NaN                NaN
# 2               NaN                           NaN                NaN
# 3               NaN                           NaN                NaN
# 4               NaN                           NaN                NaN
#
#   Etat du véhicule  Option/Equipement Confort intérieur  \
# 0              NaN                                  NaN
# 1              NaN                                  NaN
# 2              NaN                                  NaN
# 3              NaN                                  NaN
# 4              NaN                                  NaN
#
#   Option/equipement extérieurs Option equipement Sécurité
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15743 entries, 0 to 15742
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   index                                15743 non-null  int64
#  1   Version                              13237 non-null  object
#  2   Prix                                 14356 non-null  object
#  3   Année                                14363 non-null  object
#  4   Kilométrage                          14353 non-null  object
#  5   Energie                              13536 non-null  object
#  6   Emissions de CO2                     8159 non-null   float64
#  7   Consommation mixte                   2851 non-null   float64
#  8   Transmission                         12555 non-null  object
#  9   Nb de portes                         13817 non-null  object
#  10  Puissance fiscale                    13516 non-null  float64
#  11  Nombre de places                     11443 non-null  float64
#  12  Carrosserie                          10442 non-null  object
#  13  Couleur                              10344 non-null  object
#  14  Puissance réelle                     7638 non-null   float64
#  15  Autres informations                  961 non-null    object
#  16  Garantie mécanique                   3104 non-null   object
#  17  Vignette CritAir                    1016 non-null   float64
#  18  Couleur intérieur                    549 non-null    object
#  19  Type de peinture carrosserie         190 non-null    object
#  20  Contrôle technique                   171 non-null    object
#  21  Etat du véhicule                     82 non-null     object
#  22  Option/Equipement Confort intérieur  113 non-null    object
#  23  Option/equipement extérieurs         113 non-null    object
#  24  Option equipement Sécurité           107 non-null    object
# dtypes: float64(6), int64(1), object(18)
# memory usage: 3.0+ MB

# %% [markdown]
# ## Pré-nettoyage

# %%
import re 
import numpy as np

# %%
def extract_data(column, index):
    url_list = df[column].tolist()
    
    brand_model_list = []
    for url in url_list:
        if 'N/A' not in url:
            url = url.split(' ')[index]
            brand_model_list.append(url)
        else:
            brand_model_list.append(url)
            
    return brand_model_list

# %%
# columns = ['Energie', 'Transmission']
# for col in columns:
#     df[col] = extract_data(col, 2)

# %%
# df['Année'] = df['Année'].apply(lambda x: re.sub("[^\d\.]", "", f"{x}")).replace({'':np.nan})
# df['Année'] = df['Année'].astype('string').str[:4].astype('Int64')

# %%
# columns = ['Année', 'Nb de portes', 'Nombre de places']
# for col in columns:
#     df[col] = extract_data(col, 3)

# %%
# columns = ['Année', 'Prix', 'Kilométrage']

# for col in columns:  
#     df[col] = df[col].apply(lambda x: re.sub("[^\d\.]", "", f"{x}"))
#     df[col] = df[col].astype('Int64', errors='ignore')

# %%
# df = df.replace({"N/A": np.nan, '': np.nan})
# df['fuel_type'] = df['fuel_type'].str.replace('energie ', '')
# df['transmission'] = df['transmission'].str.replace('transmission ', '')
# del df['url']
# del df['status']
# # del df['emission']
# del df['fuel_usage']

# %%
df.head()
# Out:
#    index                                        Version      Prix  \
# 0      0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1      1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2      2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3      3                                            NaN       NaN
# 4      4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
#
#           Année Kilométrage  Energie  Emissions de CO2  Consommation mixte  \
# 0  Octobre 2018      30 400  Essence             139.0                 6.0
# 1      Mai 2011      66 100  Essence             142.0                 6.0
# 2     Mars 2015     129 000  Essence             150.0                 6.5
# 3           NaN         NaN      NaN               NaN                 NaN
# 4      Mai 2019      66 530  Essence             153.0                 NaN
#
#        Transmission         Nb de portes  ...  \
# 0          Manuelle  2 portes avec hayon  ...
# 1          Manuelle  2 portes avec hayon  ...
# 2  Semi automatique  2 portes avec hayon  ...
# 3               NaN                  NaN  ...
# 4          Manuelle  2 portes avec hayon  ...
#
#                  Autres informations  Garantie mécanique Vignette CritAir  \
# 0                                NaN                 NaN               NaN
# 1  Première main,Véhicule non fumeur                 NaN               NaN
# 2                                NaN                 NaN               NaN
# 3                                NaN                 NaN               NaN
# 4                                NaN                 NaN               NaN
#
#   Couleur intérieur  Type de peinture carrosserie Contrôle technique  \
# 0               NaN                           NaN                NaN
# 1               NaN                           NaN                NaN
# 2               NaN                           NaN                NaN
# 3               NaN                           NaN                NaN
# 4               NaN                           NaN                NaN
#
#   Etat du véhicule  Option/Equipement Confort intérieur  \
# 0              NaN                                  NaN
# 1              NaN                                  NaN
# 2              NaN                                  NaN
# 3              NaN                                  NaN
# 4              NaN                                  NaN
#
#   Option/equipement extérieurs Option equipement Sécurité
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Enregistrement du dataframe

# %%
# df.to_csv('data/paruvendu.csv', index=False, encoding="utf-8")

# %% [markdown]
# ## Phase exploratoire

# %%
# df.version.value_counts()

# %%
# df.fuel_type.value_counts()

# %%
# df.transmission.value_counts()

# %%
# df.body_colour.value_counts()

# %%
# df.seat_nb.value_counts()

# %% [markdown]
# ### Création d'une colonne modèle

# %%
# models = [element for key, value in brands.items() for element in value]
# models

# %%
# for element in df['version']:
#     for model in models:
#         try:
#             model = int(model)
#         except:
#             model = str(model)
#             if model in element:
#                 print(f'{element}, {model.lower()}')

# %% [markdown]
# ## Analyse de la forme des données

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.head()
# Out:
#    index                                        Version      Prix  \
# 0      0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1      1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2      2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3      3                                            NaN       NaN
# 4      4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
#
#           Année Kilométrage  Energie  Emissions de CO2  Consommation mixte  \
# 0  Octobre 2018      30 400  Essence             139.0                 6.0
# 1      Mai 2011      66 100  Essence             142.0                 6.0
# 2     Mars 2015     129 000  Essence             150.0                 6.5
# 3           NaN         NaN      NaN               NaN                 NaN
# 4      Mai 2019      66 530  Essence             153.0                 NaN
#
#        Transmission         Nb de portes  ...  \
# 0          Manuelle  2 portes avec hayon  ...
# 1          Manuelle  2 portes avec hayon  ...
# 2  Semi automatique  2 portes avec hayon  ...
# 3               NaN                  NaN  ...
# 4          Manuelle  2 portes avec hayon  ...
#
#                  Autres informations  Garantie mécanique Vignette CritAir  \
# 0                                NaN                 NaN               NaN
# 1  Première main,Véhicule non fumeur                 NaN               NaN
# 2                                NaN                 NaN               NaN
# 3                                NaN                 NaN               NaN
# 4                                NaN                 NaN               NaN
#
#   Couleur intérieur  Type de peinture carrosserie Contrôle technique  \
# 0               NaN                           NaN                NaN
# 1               NaN                           NaN                NaN
# 2               NaN                           NaN                NaN
# 3               NaN                           NaN                NaN
# 4               NaN                           NaN                NaN
#
#   Etat du véhicule  Option/Equipement Confort intérieur  \
# 0              NaN                                  NaN
# 1              NaN                                  NaN
# 2              NaN                                  NaN
# 3              NaN                                  NaN
# 4              NaN                                  NaN
#
#   Option/equipement extérieurs Option equipement Sécurité
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (15743, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15743 entries, 0 to 15742
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   index                                15743 non-null  int64
#  1   Version                              13237 non-null  object
#  2   Prix                                 14356 non-null  object
#  3   Année                                14363 non-null  object
#  4   Kilométrage                          14353 non-null  object
#  5   Energie                              13536 non-null  object
#  6   Emissions de CO2                     8159 non-null   float64
#  7   Consommation mixte                   2851 non-null   float64
#  8   Transmission                         12555 non-null  object
#  9   Nb de portes                         13817 non-null  object
#  10  Puissance fiscale                    13516 non-null  float64
#  11  Nombre de places                     11443 non-null  float64
#  12  Carrosserie                          10442 non-null  object
#  13  Couleur                              10344 non-null  object
#  14  Puissance réelle                     7638 non-null   float64
#  15  Autres informations                  961 non-null    object
#  16  Garantie mécanique                   3104 non-null   object
#  17  Vignette CritAir                    1016 non-null   float64
#  18  Couleur intérieur                    549 non-null    object
#  19  Type de peinture carrosserie         190 non-null    object
#  20  Contrôle technique                   171 non-null    object
#  21  Etat du véhicule                     82 non-null     object
#  22  Option/Equipement Confort intérieur  113 non-null    object
#  23  Option/equipement extérieurs         113 non-null    object
#  24  Option equipement Sécurité           107 non-null    object
# dtypes: float64(6), int64(1), object(18)
# memory usage: 3.0+ MB

# %%
df.dtypes.value_counts()
# Out:
# object     18
# float64     6
# int64       1
# dtype: int64

# %%
df.describe()
# Out:
#               index  Emissions de CO2  Consommation mixte  Puissance fiscale  \
# count  15743.000000       8159.000000         2851.000000       13516.000000
# mean    7871.000000        144.699963            6.075798          11.256437
# std     4544.756979         94.366720            2.542596          16.280794
# min        0.000000          1.000000            1.500000           1.000000
# 25%     3935.500000        114.000000            4.500000           6.000000
# 50%     7871.000000        130.000000            5.300000           7.000000
# 75%    11806.500000        155.000000            6.700000          10.000000
# max    15742.000000       7000.000000           22.000000         560.000000
#
#        Nombre de places  Puissance réelle  Vignette CritAir
# count      11443.000000       7638.000000        1016.000000
# mean          15.681902        173.324430           1.729331
# std         1168.487572        115.360657           0.778128
# min            2.000000          4.000000           0.000000
# 25%            5.000000        109.000000           1.000000
# 50%            5.000000        137.500000           2.000000
# 75%            5.000000        184.000000           2.000000
# max       125000.000000        799.000000           4.000000

# %%
df.isna().sum()
# Out:
# index                                      0
# Version                                 2506
# Prix                                    1387
# Année                                   1380
# Kilométrage                             1390
# Energie                                 2207
# Emissions de CO2                        7584
# Consommation mixte                     12892
# Transmission                            3188
# Nb de portes                            1926
# Puissance fiscale                       2227
# Nombre de places                        4300
# Carrosserie                             5301
# Couleur                                 5399
# Puissance réelle                        8105
# Autres informations                    14782
# Garantie mécanique                     12639
# Vignette CritAir                      14727
# Couleur intérieur                      15194
# Type de peinture carrosserie           15553
# Contrôle technique                     15572
# Etat du véhicule                       15661
# Option/Equipement Confort intérieur    15630
# Option/equipement extérieurs           15630
# Option equipement Sécurité             15636
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# Etat du véhicule                       0.994791
# Option equipement Sécurité             0.993203
# Option/Equipement Confort intérieur    0.992822
# Option/equipement extérieurs           0.992822
# Contrôle technique                     0.989138
# Type de peinture carrosserie           0.987931
# Couleur intérieur                      0.965127
# Autres informations                    0.938957
# Vignette CritAir                      0.935463
# Consommation mixte                     0.818904
# Garantie mécanique                     0.802833
# Puissance réelle                       0.514832
# Emissions de CO2                       0.481738
# Couleur                                0.342946
# Carrosserie                            0.336721
# Nombre de places                       0.273137
# Transmission                           0.202503
# Version                                0.159182
# Puissance fiscale                      0.141460
# Energie                                0.140189
# Nb de portes                           0.122340
# Kilométrage                            0.088293
# Prix                                   0.088103
# Année                                  0.087658
# index                                  0.000000
# dtype: float64

# %% [markdown]
# ## Analyse du Fond
# ### Examen de la colonne target

# %%
df.head()
# Out:
#    index                                        Version      Prix  \
# 0      0            595 1.4 Turbo 16V T-Jet 145 ch BVM5  16 200 €
# 1      1           Punto Evo 1.4 16v Turbo MultiAir 165  12 990 €
# 2      2  595 1.4 Turbo 16V T-Jet 160 ch Competizione A  15 000 €
# 3      3                                            NaN       NaN
# 4      4         1.4 Turbo T-Jet 165ch 595 Turismo 70th  17 490 €
#
#           Année Kilométrage  Energie  Emissions de CO2  Consommation mixte  \
# 0  Octobre 2018      30 400  Essence             139.0                 6.0
# 1      Mai 2011      66 100  Essence             142.0                 6.0
# 2     Mars 2015     129 000  Essence             150.0                 6.5
# 3           NaN         NaN      NaN               NaN                 NaN
# 4      Mai 2019      66 530  Essence             153.0                 NaN
#
#        Transmission         Nb de portes  ...  \
# 0          Manuelle  2 portes avec hayon  ...
# 1          Manuelle  2 portes avec hayon  ...
# 2  Semi automatique  2 portes avec hayon  ...
# 3               NaN                  NaN  ...
# 4          Manuelle  2 portes avec hayon  ...
#
#                  Autres informations  Garantie mécanique Vignette CritAir  \
# 0                                NaN                 NaN               NaN
# 1  Première main,Véhicule non fumeur                 NaN               NaN
# 2                                NaN                 NaN               NaN
# 3                                NaN                 NaN               NaN
# 4                                NaN                 NaN               NaN
#
#   Couleur intérieur  Type de peinture carrosserie Contrôle technique  \
# 0               NaN                           NaN                NaN
# 1               NaN                           NaN                NaN
# 2               NaN                           NaN                NaN
# 3               NaN                           NaN                NaN
# 4               NaN                           NaN                NaN
#
#   Etat du véhicule  Option/Equipement Confort intérieur  \
# 0              NaN                                  NaN
# 1              NaN                                  NaN
# 2              NaN                                  NaN
# 3              NaN                                  NaN
# 4              NaN                                  NaN
#
#   Option/equipement extérieurs Option equipement Sécurité
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 25 columns]

# %%
for col in df:
    print(df[col].value_counts())

# %%
# df['price'].describe()

# %%
# df['version'].value_counts(normalize=True)

# %%
# # Some data
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# fracs = [15, 30, 45, 10]

# # Make figure and axes
# fig, axs = plt.subplots(1, 2)

# # A standard pie plot
# axs[0].pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)

# # Shift the second slice using explode
# axs[1].pie(fracs, labels=labels, autopct='%.0f%%', shadow=True,
#               explode=(0, 0.1, 0, 0))

# plt.show()

# %%
df['version'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\intro-conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'version'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-7ac9e3c291dd> in <module>
# ----> 1 df['version'].value_counts()
#
# ~\anaconda3\envs\intro-conda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\intro-conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'version'

# %%
df['body_colour'].value_counts()

# %%
df['year'].value_counts().plot.pie()

# %%
df['fuel_type'].value_counts().plot.pie()

# %%
# df.groupby('fuel_type')['price'].mean().plot.pie()

# %%
df['transmission'].value_counts().plot.pie()

# %%
# df.groupby('transmission')['price'].mean().plot.pie()

# %% [markdown]
# ### Histogrames des variables continues

# %%
a

# %%
df_float = df[columns].astype('float64', errors='ignore').iloc[:, 1:]
for col in df_float.select_dtypes('float64'):
    plt.figure(figsize=(10,4))
    sns.histplot(df_float[col], kde=True, stat='density')

# %% [markdown]
# ### Relation Variables / Variables

# %%
sns.pairplot(df)

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16,10))
mask = np.triu(np.ones_like(corrmat, dtype=np.bool))
sns.heatmap(corrmat, mask=mask, vmax=.8, square=True, cbar=True, annot=True, fmt='.3f', annot_kws={'size': 10});
ax.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':14}, pad=16)

# %%
#correlation matrix
corrmat = df.corr()
sns.clustermap(corrmat, fmt='.1f');
ax.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':14}, pad=16)

# %%
df_scatter = df.copy()
df_scatter = df_scatter.dropna()

# %%
plt.rcParams["figure.figsize"] = (16,8)
df_scatter.plot.scatter(x = 'year', y = 'price')

# %%
plt.rcParams["figure.figsize"] = (16,8)
df_scatter.plot.scatter(x = 'mileage', y = 'price')
